# %%
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from typing import Dict, Tuple, List
import time
import numpy as np
from IPython import display # Jupyter環境用（オプション）

# 環境設定
GRID_SIZE = 10
NUM_AGENTS = 2
NUM_ORDERS = 3
PICKUP_LOCATIONS = [(1, 1), (8, 1), (5, 8)]
DROPOFF_LOCATION = (5, 5)

class WarehouseEnv:
    def __init__(self, size: int = GRID_SIZE, num_agents: int = NUM_AGENTS):
        self.size = size
        self.num_agents = num_agents
        self.action_space = 5  # 0:待機, 1:上, 2:下, 3:左, 4:右

        # Matplotlib用の図の保持
        self.fig = None
        self.ax = None

        # 状態の初期化
        self.reset()

    def reset(self) -> Dict[int, Tuple]:
        """環境を初期化し、初期状態を返します。"""
        self.agent_positions: Dict[int, Tuple[int, int]] = {
            i: (random.randint(0, self.size - 1), random.randint(0, self.size - 1))
            for i in range(self.num_agents)
        }
        self.agent_holding: Dict[int, bool] = {i: False for i in range(self.num_agents)}
        self.remaining_orders: List[int] = list(range(NUM_ORDERS))
        return self._get_obs()

    def _get_obs(self) -> Dict[int, Tuple]:
        obs = {}
        for i in range(self.num_agents):
            obs[i] = (
                self.agent_positions[i],
                self.agent_holding[i],
                tuple(self.remaining_orders)
            )
        return obs

    def step(self, actions: Dict[int, int]) -> Tuple[Dict, Dict, Dict, Dict]:
        next_positions: Dict[int, Tuple[int, int]] = {}
        rewards: Dict[int, float] = {i: -0.1 for i in range(self.num_agents)}

        # 1. 位置の更新
        for i, action in actions.items():
            current_x, current_y = self.agent_positions[i]
            next_x, next_y = current_x, current_y

            if action == 1: next_y += 1  # 上
            elif action == 2: next_y -= 1  # 下
            elif action == 3: next_x -= 1  # 左
            elif action == 4: next_x += 1  # 右

            next_x = np.clip(next_x, 0, self.size - 1)
            next_y = np.clip(next_y, 0, self.size - 1)
            next_positions[i] = (next_x, next_y)

        # 2. 衝突判定
        final_positions = self.agent_positions.copy()
        is_collision = False

        for i in range(self.num_agents):
            pos = next_positions[i]
            is_colliding = False
            for j in range(self.num_agents):
                if i != j and pos == next_positions[j]:
                    is_colliding = True
                    break
            if is_colliding:
                rewards[i] -= 5.0
                is_collision = True
            else:
                final_positions[i] = pos

        self.agent_positions = final_positions

        # 3. ピックアップ・ドロップオフ
        for i in range(self.num_agents):
            current_pos = self.agent_positions[i]
            if not self.agent_holding[i]:
                for order_idx in self.remaining_orders:
                    if current_pos == PICKUP_LOCATIONS[order_idx]:
                        self.agent_holding[i] = True
                        self.remaining_orders.remove(order_idx)
                        rewards[i] += 10.0
                        break
            elif self.agent_holding[i]:
                if current_pos == DROPOFF_LOCATION:
                    self.agent_holding[i] = False
                    rewards[i] += 50.0

        done = {i: len(self.remaining_orders) == 0 for i in range(self.num_agents)}
        return self._get_obs(), rewards, done, {"collision": is_collision}

    # --- 追加された可視化メソッド ---
    def render(self, mode='text', sleep_time=0.5):
        """
        環境を可視化します。
        mode='text': コンソールに文字で表示
        mode='graphic': Matplotlibで図として表示
        """
        if mode == 'text':
            self._render_text()
        elif mode == 'graphic':
            self._render_graphic(sleep_time)

    def _render_text(self):
        grid = [['.' for _ in range(self.size)] for _ in range(self.size)]

        # 場所のマーク (y座標は下から上へ増えるため、表示時は反転させるか注意が必要)
        # ここでは (0,0) を左下として扱います
        x, y = DROPOFF_LOCATION
        grid[self.size - 1 - y][x] = 'D'  # Dropoff

        for idx in self.remaining_orders:
            x, y = PICKUP_LOCATIONS[idx]
            grid[self.size - 1 - y][x] = 'P'  # Pickup

        for i, pos in self.agent_positions.items():
            x, y = pos
            char = f'A{i}'
            if self.agent_holding[i]:
                char = f'H{i}' # Holding

            # 同じ場所に重なった場合の表示処理（簡易）
            if grid[self.size - 1 - y][x] not in ['.', 'P', 'D']:
                grid[self.size - 1 - y][x] += char
            else:
                grid[self.size - 1 - y][x] = char

        print("-" * (self.size * 3))
        for row in grid:
            print(" ".join([f"{c:>2}" for c in row]))
        print("-" * (self.size * 3))

    # --- WarehouseEnv クラス内の _render_graphic メソッドの修正 ---
    # ⚠️ 注意: これは WarehouseEnv クラスの内部にあると仮定
    def _render_graphic(self, sleep_time):
        # sleep_time はここでは完全に無視される（run_learned_agent側で処理）

        if self.fig is None:
            plt.ioff() # インタラクティブモードをオフにする（描画更新はdisplayに任せる）
            self.fig, self.ax = plt.subplots(figsize=(6, 6))

        self.ax.clear()
        self.ax.set_xlim(-0.5, self.size - 0.5)
        self.ax.set_ylim(-0.5, self.size - 0.5)
        self.ax.set_xticks(range(self.size))
        self.ax.set_yticks(range(self.size))
        self.ax.grid(True)
        self.ax.set_title(f"Orders Remaining: {len(self.remaining_orders)}")

        # ドロップオフ地点 (赤色)
        dx, dy = DROPOFF_LOCATION
        self.ax.add_patch(patches.Rectangle((dx-0.5, dy-0.5), 1, 1, color='red', alpha=0.3, label='Dropoff'))
        self.ax.text(dx, dy, 'Drop', ha='center', va='center', fontsize=8, color='darkred')

        # ピックアップ地点 (青色)
        for idx in self.remaining_orders:
            px, py = PICKUP_LOCATIONS[idx]
            self.ax.add_patch(patches.Rectangle((px-0.5, py-0.5), 1, 1, color='blue', alpha=0.3, label='Pickup'))
            self.ax.text(px, py, 'Pick', ha='center', va='center', fontsize=8, color='darkblue')

        # エージェント (円)
        colors = ['green', 'orange', 'purple', 'cyan']
        for i, pos in self.agent_positions.items():
            ax, ay = pos
            color = colors[i % len(colors)]
            edgecolor = 'black'
            linewidth = 1
            if self.agent_holding[i]:
                linewidth = 3
                edgecolor = 'red' # 荷物持ち強調

            circle = patches.Circle((ax, ay), 0.3, facecolor=color, edgecolor=edgecolor, linewidth=linewidth, label=f'Agent {i}')
            self.ax.add_patch(circle)
            self.ax.text(ax, ay, f'A{i}', ha='center', va='center', color='white', fontweight='bold')

        # 🚨 描画更新と待機を削除！ (run_learned_agent側で処理する)
        # plt.draw()
        # if sleep_time > 0.0:
        #   plt.pause(sleep_time)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class RNNAgent(nn.Module):
    def __init__(self, input_shape, hidden_dim, n_actions):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.n_actions = n_actions

        # 観測を入力とする線形層
        self.fc1 = nn.Linear(input_shape, hidden_dim)
        # 履歴を扱うGRUセル
        self.rnn = nn.GRUCell(hidden_dim, hidden_dim)
        # 隠れ状態から行動のQ値を出力する線形層
        self.fc2 = nn.Linear(hidden_dim, n_actions)

    def init_hidden(self):
        # 隠れ状態をゼロで初期化
        return self.fc1.weight.new_zeros(1, self.hidden_dim)

    def forward(self, inputs, hidden_state):
        # inputs: 局所的な観測 (obs_i)
        # hidden_state: 前ステップの隠れ状態 (h_t-1)

        x = F.relu(self.fc1(inputs))
        # GRUによる隠れ状態の更新
        h_in = hidden_state.reshape(-1, self.hidden_dim)
        h = self.rnn(x, h_in)
        # Q値の出力
        q = self.fc2(h)
        return q, h # Q値と新しい隠れ状態を返す

#

# %%
class QMixer(nn.Module):
    def __init__(self, n_agents, state_shape, mixing_embed_dim, hypernet_embed_dim):
        super().__init__()
        self.n_agents = n_agents
        self.mixing_embed_dim = mixing_embed_dim
        # 1. ハイパーネットワークの定義
        # 環境状態 (state) を入力とし、Mixing Networkの重みW1を生成
        self.hyper_w1 = nn.Sequential(
            nn.Linear(state_shape, hypernet_embed_dim),
            nn.ReLU(),
            nn.Linear(hypernet_embed_dim, mixing_embed_dim * n_agents)
        )

        # バイアスb1も環境状態から生成
        self.hyper_b1 = nn.Linear(state_shape, mixing_embed_dim)

        # W2 (Mixing Networkの2層目の重み) を生成
        self.hyper_w2 = nn.Sequential(
            nn.Linear(state_shape, hypernet_embed_dim),
            nn.ReLU(),
            nn.Linear(hypernet_embed_dim, mixing_embed_dim)
        )

        # バイアスb2 (最終出力層のバイアス) を環境状態から生成
        self.hyper_b2 = nn.Sequential(
            nn.Linear(state_shape, hypernet_embed_dim),
            nn.ReLU(),
            nn.Linear(hypernet_embed_dim, 1)
        )

        # 2. 最終出力層（ダミー）
        # 実際にはハイパーネットワークが生成した重みで演算するが、サイズ調整のために定義
        self.V = nn.Sequential(nn.Linear(state_shape, mixing_embed_dim), nn.ReLU(), nn.Linear(mixing_embed_dim, 1))

    def forward(self, agent_qs, states):
        # agent_qs: 全エージェントのQ値 (batch_size, n_agents)
        # states: 環境の全体状態 (batch_size, state_shape)

        bs = agent_qs.size(0)

        # 1. 隠れ層 W1 の計算 (重みの生成と非負制約)
        W1 = self.hyper_w1(states).view(bs, self.n_agents, self.mixing_embed_dim)
        # 非負制約: 重みをReLUに通す
        W1 = F.relu(W1)

        # 2. 隠れ層 B1 (バイアス) の計算
        B1 = self.hyper_b1(states).view(bs, 1, self.mixing_embed_dim)

        # 3. 第1層の計算: (Q_i * W1) + B1
        # agent_qs: (bs, 1, n_agents), W1: (bs, n_agents, mixing_embed_dim)
        hidden = torch.bmm(agent_qs.unsqueeze(1), W1)
        # hidden: (bs, 1, mixing_embed_dim)
        hidden = F.relu(hidden + B1)

        # 4. 出力層 W2 の計算 (重みの生成と非負制約)
        W2 = self.hyper_w2(states).view(bs, self.mixing_embed_dim, 1)
        # 非負制約: 重みをReLUに通す
        W2 = F.relu(W2)

        # 5. 出力層 B2 (バイアス) の計算
        B2 = self.hyper_b2(states).view(bs, 1, 1)

        # 6. 第2層の計算: (hidden * W2) + B2
        # V(s)項 (全エージェントに共通のバイアス項)
        v = self.V(states).view(bs, 1, 1)

        # 最終的なQ_totの出力
        q_tot = torch.bmm(hidden, W2) + B2 + v
        # q_tot: (batch_size, 1, 1)
        return q_tot.squeeze()

#

# %%
from collections import deque
import random

class ReplayBuffer:
    """QMIX学習に必要なトランジションを格納するリプレイバッファ"""
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
        self.capacity = capacity

    def add(self, state, action, reward, next_state, done):
        # 倉庫環境の出力形式を考慮し、エージェントごとの情報を格納
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        if len(self.buffer) < batch_size:
            return None
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

#

# %%
# --- QMIX構成要素のインポート（前の回答のクラス定義を仮定） ---
# import torch, torch.nn, torch.nn.functional
# from RNNAgent import RNNAgent
# from QMixer import QMixer
# ... (実際には上記のクラス定義が必要です)

# QMixAgentの学習ロジックを統合するクラス
class IntegratedQMixAgent:
    def __init__(self, env: WarehouseEnv, obs_shape: int, state_shape: int, n_actions: int, lr=5e-4, gamma=0.99, mixing_embed_dim=32):
        self.env = env
        self.n_agents = env.num_agents
        self.n_actions = n_actions
        self.gamma = gamma
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        # RNNの隠れ状態をエージェントごとに保持
        self.hidden_states = {i: None for i in range(self.n_agents)}

        # ネットワークの初期化
        self.agent_net = RNNAgent(obs_shape, hidden_dim=64, n_actions=n_actions).to(self.device)
        self.mixer_net = QMixer(self.n_agents, state_shape, mixing_embed_dim, hypernet_embed_dim=64).to(self.device)

        self.target_agent_net = RNNAgent(obs_shape, hidden_dim=64, n_actions=n_actions).to(self.device)
        self.target_mixer_net = QMixer(self.n_agents, state_shape, mixing_embed_dim, hypernet_embed_dim=64).to(self.device)

        self.target_agent_net.load_state_dict(self.agent_net.state_dict())
        self.target_mixer_net.load_state_dict(self.mixer_net.state_dict())

        params = list(self.agent_net.parameters()) + list(self.mixer_net.parameters())
        self.optimizer = torch.optim.Adam(params, lr=lr)

    def init_hidden(self):
        """エピソード開始時に隠れ状態を初期化"""
        for i in range(self.n_agents):
            self.hidden_states[i] = self.agent_net.init_hidden().to(self.device)

    def _obs_to_tensor(self, obs: Dict[int, Tuple], is_state: bool = False):
        """環境の観測/状態をPyTorchテンソルに変換"""
        if is_state:
            # 全体状態 (全エージェントの位置 + 残り注文)
            state_vec = []
            for i in range(self.n_agents):
                state_vec.extend(list(obs[i][0])) # Agent i の位置 (x, y)
                state_vec.append(1.0 if obs[i][1] else 0.0) # Agent i が荷物を持っているか

            # 残り注文のOne-Hotエンコーディング (簡略化)
            remaining_orders_set = set(obs[0][2])
            for order_idx in range(NUM_ORDERS):
                state_vec.append(1.0 if order_idx in remaining_orders_set else 0.0)

            return torch.FloatTensor(state_vec).to(self.device).unsqueeze(0)
        else:
            # 局所観測 (Agent i の位置, 荷物持ち)
            tensors = {}
            for i in range(self.n_agents):
                obs_i = list(obs[i][0]) # 位置 (x, y)
                obs_i.append(1.0 if obs[i][1] else 0.0) # 荷物持ち

                # 敵エージェントの位置や状態も観測に入れる場合はここで拡張するが、ここでは局所観測のみ

                tensors[i] = torch.FloatTensor(obs_i).to(self.device).unsqueeze(0)
            return tensors

    def get_actions(self, obs: Dict[int, Tuple], epsilon: float) -> Dict[int, int]:
        """epsilon-greedy法で行動を選択し、隠れ状態を更新"""
        actions = {}
        if random.random() < epsilon:
            # 探索 (Exploration)
            for i in range(self.n_agents):
                actions[i] = random.randint(0, self.n_actions - 1)
        else:
            # 活用 (Exploitation)
            agent_obs_tensors = self._obs_to_tensor(obs, is_state=False)
            with torch.no_grad():
                for i in range(self.n_agents):
                    q_values, h_new = self.agent_net(agent_obs_tensors[i], self.hidden_states[i])
                    self.hidden_states[i] = h_new # 隠れ状態を更新
                    actions[i] = q_values.max(dim=-1)[1].item()
        return actions

    def learn(self, batch, target_update_interval):
        """バッチからサンプリングし、QMIX損失で学習"""

        # --- データ変換 ---
        # NOTE: 実際の学習では、リプレイバッファに格納する際にRNNの履歴（隠れ状態）も格納するのが一般的ですが、
        # ここでは簡略化し、バッチ内の各ステップを独立したトランジションとして扱います。

        current_state = torch.cat([self._obs_to_tensor(t[0], is_state=True) for t in batch], dim=0)
        next_state = torch.cat([self._obs_to_tensor(t[3], is_state=True) for t in batch], dim=0)
        rewards = torch.FloatTensor([sum(t[2].values()) for t in batch]).to(self.device) # チーム合計報酬
        terminated = torch.FloatTensor([all(t[4].values()) for t in batch]).to(self.device) # 終了フラグ

        # エージェントごとのアクション、観測をバッチ化
        actions_batch = torch.LongTensor([[t[1][i] for i in range(self.n_agents)] for t in batch]).to(self.device)
        obs_batch = [torch.cat([self._obs_to_tensor(t[0], is_state=False)[i] for t in batch], dim=0) for i in range(self.n_agents)]
        next_obs_batch = [torch.cat([self._obs_to_tensor(t[3], is_state=False)[i] for t in batch], dim=0) for i in range(self.n_agents)]

        # 1. 現在のQ_totの計算 (Hidden Stateはここではゼロ初期化)
        agent_qs = []
        for i in range(self.n_agents):
            # Q値を計算
            q_vals, _ = self.agent_net(obs_batch[i], self.agent_net.init_hidden().expand(len(batch), -1))
            # 実行されたアクションのQ値を選択
            chosen_q = torch.gather(q_vals, dim=1, index=actions_batch[:, i].unsqueeze(1))
            agent_qs.append(chosen_q)

        agent_qs = torch.cat(agent_qs, dim=1) # (batch_size, n_agents)
        q_tot = self.mixer_net(agent_qs, current_state)

        # 2. TDターゲットの計算 (Target Q_tot)
        target_agent_qs = []
        with torch.no_grad():
            for i in range(self.n_agents):
                target_q_vals, _ = self.target_agent_net(next_obs_batch[i], self.target_agent_net.init_hidden().expand(len(batch), -1))
                # 最大Q値を選択
                target_max_q = target_q_vals.max(dim=1)[0].unsqueeze(1)
                target_agent_qs.append(target_max_q)

            target_agent_qs = torch.cat(target_agent_qs, dim=1)
            target_q_tot = self.target_mixer_net(target_agent_qs, next_state)

        # ターゲット値: R + gamma * max Q_next * (1 - done)
        td_target = rewards.unsqueeze(1) + self.gamma * target_q_tot * (1 - terminated.unsqueeze(1))

        # 3. 損失の計算と最適化
        loss = F.mse_loss(q_tot, td_target.detach())

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        return loss.item()

    def update_target_networks(self):
        """ターゲットネットワークの重みを更新"""
        self.target_agent_net.load_state_dict(self.agent_net.state_dict())
        self.target_mixer_net.load_state_dict(self.mixer_net.state_dict())

# %%
# --- 学習パラメータ ---
MAX_EPISODES = 5000
MAX_STEPS_PER_EPISODE = 200
BATCH_SIZE = 32
REPLAY_CAPACITY = 50000
TARGET_UPDATE_INTERVAL = 200 # ステップ数でターゲットネットワークを更新
EPSILON_START = 1.0
EPSILON_END = 0.05
EPSILON_DECAY = 40000

# 環境とエージェントの準備
env = WarehouseEnv()

# --- 観測/状態のサイズを計算 ---
# 局所観測: (x, y, holding) -> 3
OBS_SHAPE = 3
# 全体状態: (A0のx, A0のy, A0のholding, A1のx, A1のy, A1のholding, P0_status, P1_status, P2_status) -> 2*3 + 3 = 9
STATE_SHAPE = env.num_agents * 3 + NUM_ORDERS
ACTION_SPACE = env.action_space

# QMixAgentの初期化
agent = IntegratedQMixAgent(env, OBS_SHAPE, STATE_SHAPE, ACTION_SPACE)
replay_buffer = ReplayBuffer(REPLAY_CAPACITY)

total_steps = 0
episode_rewards = []
losses = []

# %%
print(f"--- QMIX Learning Start --- (Agents: {NUM_AGENTS}, Grid: {GRID_SIZE}x{GRID_SIZE})")

for episode in range(MAX_EPISODES):
    obs = env.reset()
    agent.init_hidden()

    current_state_obs = obs # ステップ前の状態を格納 (ログ用)
    episode_reward = 0
    done = {i: False for i in range(env.num_agents)}

    for step in range(MAX_STEPS_PER_EPISODE):
        total_steps += 1

        # 1. epsilonの減衰
        epsilon = max(EPSILON_END, EPSILON_START - (total_steps / EPSILON_DECAY))

        # 2. 行動の選択
        actions = agent.get_actions(current_state_obs, epsilon)

        # 3. 環境との相互作用
        next_obs, rewards, done, info = env.step(actions)

        # 4. リプレイバッファに格納 (全体状態としてログに記録)
        # NOTE: QMIXではRNNの隠れ状態も格納することが推奨されますが、ここでは簡略化
        replay_buffer.add(current_state_obs, actions, rewards, next_obs, done)

        # 5. 学習 (バッファが十分溜まったら実行)
        if len(replay_buffer) > BATCH_SIZE * 5 and total_steps % 4 == 0:
            batch = replay_buffer.sample(BATCH_SIZE)
            loss = agent.learn(batch, TARGET_UPDATE_INTERVAL)
            losses.append(loss)

            # ターゲットネットワークの更新
            if total_steps % TARGET_UPDATE_INTERVAL == 0:
                agent.update_target_networks()

        # 報酬の集計と状態の更新
        episode_reward += sum(rewards.values())
        current_state_obs = next_obs

        # 可視化 (任意)
        if episode % 500 == 0 and step % 20 == 0:
            env.render(mode='graphic', sleep_time=0.01)

        if all(done.values()):
            break

    episode_rewards.append(episode_reward)

    # ログ出力
    if episode % 10 == 0:
        avg_reward = np.mean(episode_rewards[-100:])
        avg_loss = np.mean(losses[-100:]) if losses else 0
        print(f"Episode: {episode}/{MAX_EPISODES}, Steps: {total_steps}, Avg. Reward (100): {avg_reward:.2f}, Epsilon: {epsilon:.2f}, Avg. Loss: {avg_loss:.4f}")

print("--- QMIX Learning Finished ---")

# 学習結果のプロット (任意)
plt.figure(figsize=(10, 5))
plt.plot(episode_rewards)
plt.title("Episode Reward History")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.show()
# Out:
# --- QMIX Learning Start --- (Agents: 2, Grid: 10x10)
# /tmp/ipython-input-2611040031.py:126: UserWarning: Using a target size (torch.Size([32, 32])) that is different to the input size (torch.Size([32])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss = F.mse_loss(q_tot, td_target.detach())
# Episode: 0/5000, Steps: 200, Avg. Reward (100): 0.00, Epsilon: 0.99, Avg. Loss: 7.1888
# Episode: 10/5000, Steps: 2138, Avg. Reward (100): -4.33, Epsilon: 0.95, Avg. Loss: 27.8720
# Episode: 20/5000, Steps: 4105, Avg. Reward (100): -11.48, Epsilon: 0.90, Avg. Loss: 219.4433
# Episode: 30/5000, Steps: 6059, Avg. Reward (100): -14.25, Epsilon: 0.85, Avg. Loss: 945.3856
# Episode: 40/5000, Steps: 8059, Avg. Reward (100): -16.14, Epsilon: 0.80, Avg. Loss: 2302.7197
# Episode: 50/5000, Steps: 10059, Avg. Reward (100): -23.17, Epsilon: 0.75, Avg. Loss: 4684.7958
# Episode: 60/5000, Steps: 12059, Avg. Reward (100): -28.06, Epsilon: 0.70, Avg. Loss: 3551.9666
# Episode: 70/5000, Steps: 14059, Avg. Reward (100): -34.39, Epsilon: 0.65, Avg. Loss: 3909.2820
# Episode: 80/5000, Steps: 16059, Avg. Reward (100): -41.50, Epsilon: 0.60, Avg. Loss: 2082.8431
# Episode: 90/5000, Steps: 17997, Avg. Reward (100): -44.50, Epsilon: 0.55, Avg. Loss: 7203.4422
# Episode: 100/5000, Steps: 19997, Avg. Reward (100): -51.89, Epsilon: 0.50, Avg. Loss: 1726.6590
# Episode: 110/5000, Steps: 21997, Avg. Reward (100): -65.22, Epsilon: 0.45, Avg. Loss: 1824.0395
# Episode: 120/5000, Steps: 23997, Avg. Reward (100): -75.48, Epsilon: 0.40, Avg. Loss: 2223.7363
# Episode: 130/5000, Steps: 25997, Avg. Reward (100): -108.98, Epsilon: 0.35, Avg. Loss: 2284.4302
# Episode: 140/5000, Steps: 27997, Avg. Reward (100): -158.48, Epsilon: 0.30, Avg. Loss: 4492.6464
# Episode: 150/5000, Steps: 29997, Avg. Reward (100): -160.98, Epsilon: 0.25, Avg. Loss: 1534.7303
# Episode: 160/5000, Steps: 31997, Avg. Reward (100): -171.28, Epsilon: 0.20, Avg. Loss: 3578.4297
# Episode: 170/5000, Steps: 33997, Avg. Reward (100): -188.18, Epsilon: 0.15, Avg. Loss: 999.1790
# Episode: 180/5000, Steps: 35997, Avg. Reward (100): -215.48, Epsilon: 0.10, Avg. Loss: 890.5031
# Episode: 190/5000, Steps: 37997, Avg. Reward (100): -217.40, Epsilon: 0.05, Avg. Loss: 862.2768
# Episode: 200/5000, Steps: 39997, Avg. Reward (100): -239.10, Epsilon: 0.05, Avg. Loss: 3584.7579
# Episode: 210/5000, Steps: 41997, Avg. Reward (100): -239.80, Epsilon: 0.05, Avg. Loss: 1083.5610
# Episode: 220/5000, Steps: 43997, Avg. Reward (100): -254.70, Epsilon: 0.05, Avg. Loss: 720.7334
# Episode: 230/5000, Steps: 45997, Avg. Reward (100): -227.10, Epsilon: 0.05, Avg. Loss: 849.0608
# Episode: 240/5000, Steps: 47997, Avg. Reward (100): -197.20, Epsilon: 0.05, Avg. Loss: 547.9994
# Episode: 250/5000, Steps: 49997, Avg. Reward (100): -219.20, Epsilon: 0.05, Avg. Loss: 695.5725
# Episode: 260/5000, Steps: 51997, Avg. Reward (100): -227.00, Epsilon: 0.05, Avg. Loss: 342.5261
# Episode: 270/5000, Steps: 53997, Avg. Reward (100): -237.60, Epsilon: 0.05, Avg. Loss: 403.9909
# Episode: 280/5000, Steps: 55997, Avg. Reward (100): -228.20, Epsilon: 0.05, Avg. Loss: 236.8354
# Episode: 290/5000, Steps: 57997, Avg. Reward (100): -244.50, Epsilon: 0.05, Avg. Loss: 206.9165
# Episode: 300/5000, Steps: 59997, Avg. Reward (100): -282.60, Epsilon: 0.05, Avg. Loss: 237.4485
# Episode: 310/5000, Steps: 61997, Avg. Reward (100): -283.70, Epsilon: 0.05, Avg. Loss: 138.5663
# Episode: 320/5000, Steps: 63997, Avg. Reward (100): -305.90, Epsilon: 0.05, Avg. Loss: 122.5214
# Episode: 330/5000, Steps: 65997, Avg. Reward (100): -339.00, Epsilon: 0.05, Avg. Loss: 135.6293
# Episode: 340/5000, Steps: 67997, Avg. Reward (100): -373.80, Epsilon: 0.05, Avg. Loss: 116.3735
# Episode: 350/5000, Steps: 69997, Avg. Reward (100): -373.30, Epsilon: 0.05, Avg. Loss: 170.0563
# Episode: 360/5000, Steps: 71997, Avg. Reward (100): -406.40, Epsilon: 0.05, Avg. Loss: 68.4286
# Episode: 370/5000, Steps: 73997, Avg. Reward (100): -428.50, Epsilon: 0.05, Avg. Loss: 62.0258
# Episode: 380/5000, Steps: 75997, Avg. Reward (100): -432.20, Epsilon: 0.05, Avg. Loss: 50.4890
# Episode: 390/5000, Steps: 77997, Avg. Reward (100): -443.80, Epsilon: 0.05, Avg. Loss: 55.2327
# Episode: 400/5000, Steps: 79997, Avg. Reward (100): -393.10, Epsilon: 0.05, Avg. Loss: 36.6466
# Episode: 410/5000, Steps: 81997, Avg. Reward (100): -406.10, Epsilon: 0.05, Avg. Loss: 41.2007
# Episode: 420/5000, Steps: 83997, Avg. Reward (100): -364.10, Epsilon: 0.05, Avg. Loss: 44.5619
# Episode: 430/5000, Steps: 85997, Avg. Reward (100): -339.10, Epsilon: 0.05, Avg. Loss: 86.4591
# Episode: 440/5000, Steps: 87997, Avg. Reward (100): -309.50, Epsilon: 0.05, Avg. Loss: 60.4059
# Episode: 450/5000, Steps: 89997, Avg. Reward (100): -334.10, Epsilon: 0.05, Avg. Loss: 57.0840
# Episode: 460/5000, Steps: 91997, Avg. Reward (100): -295.60, Epsilon: 0.05, Avg. Loss: 64.6025
# Episode: 470/5000, Steps: 93997, Avg. Reward (100): -256.10, Epsilon: 0.05, Avg. Loss: 68.8553
# Episode: 480/5000, Steps: 95997, Avg. Reward (100): -264.40, Epsilon: 0.05, Avg. Loss: 61.3872
# Episode: 490/5000, Steps: 97997, Avg. Reward (100): -259.90, Epsilon: 0.05, Avg. Loss: 100.2350
# Episode: 500/5000, Steps: 99997, Avg. Reward (100): -268.90, Epsilon: 0.05, Avg. Loss: 106.1815
# Episode: 510/5000, Steps: 101997, Avg. Reward (100): -249.10, Epsilon: 0.05, Avg. Loss: 115.9870
# Episode: 520/5000, Steps: 103997, Avg. Reward (100): -250.70, Epsilon: 0.05, Avg. Loss: 130.9125
# Episode: 530/5000, Steps: 105997, Avg. Reward (100): -271.50, Epsilon: 0.05, Avg. Loss: 121.8704
# Episode: 540/5000, Steps: 107997, Avg. Reward (100): -294.20, Epsilon: 0.05, Avg. Loss: 112.6250
# Episode: 550/5000, Steps: 109997, Avg. Reward (100): -286.20, Epsilon: 0.05, Avg. Loss: 111.5501
# Episode: 560/5000, Steps: 111997, Avg. Reward (100): -301.00, Epsilon: 0.05, Avg. Loss: 132.6443
# Episode: 570/5000, Steps: 113997, Avg. Reward (100): -301.20, Epsilon: 0.05, Avg. Loss: 107.8906
# Episode: 580/5000, Steps: 115997, Avg. Reward (100): -268.70, Epsilon: 0.05, Avg. Loss: 139.3698
# Episode: 590/5000, Steps: 117997, Avg. Reward (100): -267.10, Epsilon: 0.05, Avg. Loss: 103.7986
# Episode: 600/5000, Steps: 119997, Avg. Reward (100): -262.40, Epsilon: 0.05, Avg. Loss: 99.3677
# Episode: 610/5000, Steps: 121997, Avg. Reward (100): -278.80, Epsilon: 0.05, Avg. Loss: 85.1248
# Episode: 620/5000, Steps: 123997, Avg. Reward (100): -279.90, Epsilon: 0.05, Avg. Loss: 126.9985
# Episode: 630/5000, Steps: 125997, Avg. Reward (100): -318.20, Epsilon: 0.05, Avg. Loss: 91.9470
# Episode: 640/5000, Steps: 127997, Avg. Reward (100): -294.70, Epsilon: 0.05, Avg. Loss: 74.7663
# Episode: 650/5000, Steps: 129997, Avg. Reward (100): -279.00, Epsilon: 0.05, Avg. Loss: 80.7169
# Episode: 660/5000, Steps: 131997, Avg. Reward (100): -309.40, Epsilon: 0.05, Avg. Loss: 90.9960
# Episode: 670/5000, Steps: 133997, Avg. Reward (100): -325.70, Epsilon: 0.05, Avg. Loss: 90.9396
# Episode: 680/5000, Steps: 135997, Avg. Reward (100): -385.10, Epsilon: 0.05, Avg. Loss: 81.6520
# Episode: 690/5000, Steps: 137997, Avg. Reward (100): -383.70, Epsilon: 0.05, Avg. Loss: 55.7774
# Episode: 700/5000, Steps: 139997, Avg. Reward (100): -375.00, Epsilon: 0.05, Avg. Loss: 58.0002
# Episode: 710/5000, Steps: 141997, Avg. Reward (100): -353.60, Epsilon: 0.05, Avg. Loss: 60.6645
# Episode: 720/5000, Steps: 143997, Avg. Reward (100): -347.30, Epsilon: 0.05, Avg. Loss: 67.6668
# Episode: 730/5000, Steps: 145997, Avg. Reward (100): -292.90, Epsilon: 0.05, Avg. Loss: 51.0002
# Episode: 740/5000, Steps: 147997, Avg. Reward (100): -279.80, Epsilon: 0.05, Avg. Loss: 45.8601
# Episode: 750/5000, Steps: 149997, Avg. Reward (100): -273.30, Epsilon: 0.05, Avg. Loss: 62.0482
# Episode: 760/5000, Steps: 151997, Avg. Reward (100): -221.50, Epsilon: 0.05, Avg. Loss: 64.1077
# Episode: 770/5000, Steps: 153997, Avg. Reward (100): -192.90, Epsilon: 0.05, Avg. Loss: 93.5244
# Episode: 780/5000, Steps: 155997, Avg. Reward (100): -142.90, Epsilon: 0.05, Avg. Loss: 85.0285
# Episode: 790/5000, Steps: 157997, Avg. Reward (100): -139.30, Epsilon: 0.05, Avg. Loss: 89.9349
# Episode: 800/5000, Steps: 159997, Avg. Reward (100): -168.70, Epsilon: 0.05, Avg. Loss: 130.6619
# Episode: 810/5000, Steps: 161997, Avg. Reward (100): -182.00, Epsilon: 0.05, Avg. Loss: 108.0984
# Episode: 820/5000, Steps: 163997, Avg. Reward (100): -191.30, Epsilon: 0.05, Avg. Loss: 139.1218
# Episode: 830/5000, Steps: 165997, Avg. Reward (100): -179.00, Epsilon: 0.05, Avg. Loss: 143.9591
# Episode: 840/5000, Steps: 167997, Avg. Reward (100): -174.50, Epsilon: 0.05, Avg. Loss: 217.3487
# Episode: 850/5000, Steps: 169997, Avg. Reward (100): -155.90, Epsilon: 0.05, Avg. Loss: 189.4267
# Episode: 860/5000, Steps: 171997, Avg. Reward (100): -158.00, Epsilon: 0.05, Avg. Loss: 242.5836
# Episode: 870/5000, Steps: 173997, Avg. Reward (100): -167.40, Epsilon: 0.05, Avg. Loss: 331.2117
# Episode: 880/5000, Steps: 175997, Avg. Reward (100): -157.50, Epsilon: 0.05, Avg. Loss: 227.8412
# Episode: 890/5000, Steps: 177997, Avg. Reward (100): -146.40, Epsilon: 0.05, Avg. Loss: 232.5606
# Episode: 900/5000, Steps: 179997, Avg. Reward (100): -112.30, Epsilon: 0.05, Avg. Loss: 270.7081
# Episode: 910/5000, Steps: 181997, Avg. Reward (100): -106.30, Epsilon: 0.05, Avg. Loss: 220.2107
# Episode: 920/5000, Steps: 183997, Avg. Reward (100): -104.50, Epsilon: 0.05, Avg. Loss: 177.1213
# Episode: 930/5000, Steps: 185997, Avg. Reward (100): -132.60, Epsilon: 0.05, Avg. Loss: 226.5588
# Episode: 940/5000, Steps: 187997, Avg. Reward (100): -141.70, Epsilon: 0.05, Avg. Loss: 157.7736
# Episode: 950/5000, Steps: 189997, Avg. Reward (100): -189.50, Epsilon: 0.05, Avg. Loss: 229.5027
# Episode: 960/5000, Steps: 191997, Avg. Reward (100): -193.70, Epsilon: 0.05, Avg. Loss: 177.9635
# Episode: 970/5000, Steps: 193997, Avg. Reward (100): -195.80, Epsilon: 0.05, Avg. Loss: 197.2131
# Episode: 980/5000, Steps: 195997, Avg. Reward (100): -227.70, Epsilon: 0.05, Avg. Loss: 509.2876
# Episode: 990/5000, Steps: 197997, Avg. Reward (100): -226.80, Epsilon: 0.05, Avg. Loss: 433.8079
# Episode: 1000/5000, Steps: 199997, Avg. Reward (100): -239.60, Epsilon: 0.05, Avg. Loss: 425.0704
# Episode: 1010/5000, Steps: 201997, Avg. Reward (100): -233.20, Epsilon: 0.05, Avg. Loss: 545.9497
# Episode: 1020/5000, Steps: 203997, Avg. Reward (100): -243.90, Epsilon: 0.05, Avg. Loss: 259.2234
# Episode: 1030/5000, Steps: 205997, Avg. Reward (100): -219.40, Epsilon: 0.05, Avg. Loss: 274.4199
# Episode: 1040/5000, Steps: 207997, Avg. Reward (100): -234.90, Epsilon: 0.05, Avg. Loss: 287.1136
# Episode: 1050/5000, Steps: 209997, Avg. Reward (100): -203.00, Epsilon: 0.05, Avg. Loss: 427.6868
# Episode: 1060/5000, Steps: 211997, Avg. Reward (100): -214.60, Epsilon: 0.05, Avg. Loss: 205.6144
# Episode: 1070/5000, Steps: 213997, Avg. Reward (100): -237.20, Epsilon: 0.05, Avg. Loss: 380.9524
# Episode: 1080/5000, Steps: 215997, Avg. Reward (100): -215.20, Epsilon: 0.05, Avg. Loss: 208.2673
# Episode: 1090/5000, Steps: 217997, Avg. Reward (100): -206.10, Epsilon: 0.05, Avg. Loss: 249.1645
# Episode: 1100/5000, Steps: 219997, Avg. Reward (100): -198.00, Epsilon: 0.05, Avg. Loss: 200.5407
# Episode: 1110/5000, Steps: 221997, Avg. Reward (100): -214.60, Epsilon: 0.05, Avg. Loss: 231.8989
# Episode: 1120/5000, Steps: 223997, Avg. Reward (100): -209.00, Epsilon: 0.05, Avg. Loss: 372.2487
# Episode: 1130/5000, Steps: 225997, Avg. Reward (100): -200.80, Epsilon: 0.05, Avg. Loss: 226.0169
# Episode: 1140/5000, Steps: 227997, Avg. Reward (100): -174.00, Epsilon: 0.05, Avg. Loss: 215.9403
# Episode: 1150/5000, Steps: 229997, Avg. Reward (100): -191.30, Epsilon: 0.05, Avg. Loss: 206.1113
# Episode: 1160/5000, Steps: 231997, Avg. Reward (100): -202.90, Epsilon: 0.05, Avg. Loss: 188.0324
# Episode: 1170/5000, Steps: 233997, Avg. Reward (100): -176.10, Epsilon: 0.05, Avg. Loss: 256.5693
# Episode: 1180/5000, Steps: 235997, Avg. Reward (100): -213.90, Epsilon: 0.05, Avg. Loss: 193.4782
# Episode: 1190/5000, Steps: 237997, Avg. Reward (100): -230.20, Epsilon: 0.05, Avg. Loss: 211.9849
# Episode: 1200/5000, Steps: 239997, Avg. Reward (100): -227.80, Epsilon: 0.05, Avg. Loss: 161.6953
# Episode: 1210/5000, Steps: 241997, Avg. Reward (100): -219.40, Epsilon: 0.05, Avg. Loss: 163.8306
# Episode: 1220/5000, Steps: 243997, Avg. Reward (100): -207.90, Epsilon: 0.05, Avg. Loss: 191.3840
# Episode: 1230/5000, Steps: 245997, Avg. Reward (100): -229.90, Epsilon: 0.05, Avg. Loss: 135.2889
# Episode: 1240/5000, Steps: 247997, Avg. Reward (100): -242.80, Epsilon: 0.05, Avg. Loss: 167.7565
# Episode: 1250/5000, Steps: 249997, Avg. Reward (100): -212.30, Epsilon: 0.05, Avg. Loss: 120.2716
# Episode: 1260/5000, Steps: 251997, Avg. Reward (100): -193.60, Epsilon: 0.05, Avg. Loss: 208.6550
# Episode: 1270/5000, Steps: 253997, Avg. Reward (100): -223.80, Epsilon: 0.05, Avg. Loss: 153.0500
# Episode: 1280/5000, Steps: 255997, Avg. Reward (100): -192.40, Epsilon: 0.05, Avg. Loss: 221.7709
# Episode: 1290/5000, Steps: 257997, Avg. Reward (100): -192.80, Epsilon: 0.05, Avg. Loss: 194.1528
# Episode: 1300/5000, Steps: 259997, Avg. Reward (100): -187.20, Epsilon: 0.05, Avg. Loss: 110.7428
# Episode: 1310/5000, Steps: 261997, Avg. Reward (100): -181.70, Epsilon: 0.05, Avg. Loss: 102.2011
# Episode: 1320/5000, Steps: 263997, Avg. Reward (100): -215.00, Epsilon: 0.05, Avg. Loss: 192.3584
# Episode: 1330/5000, Steps: 265997, Avg. Reward (100): -200.90, Epsilon: 0.05, Avg. Loss: 180.4744
# Episode: 1340/5000, Steps: 267997, Avg. Reward (100): -193.00, Epsilon: 0.05, Avg. Loss: 171.5571
# Episode: 1350/5000, Steps: 269997, Avg. Reward (100): -218.80, Epsilon: 0.05, Avg. Loss: 132.4303
# Episode: 1360/5000, Steps: 271997, Avg. Reward (100): -204.40, Epsilon: 0.05, Avg. Loss: 173.9406
# Episode: 1370/5000, Steps: 273997, Avg. Reward (100): -178.30, Epsilon: 0.05, Avg. Loss: 126.7381
# Episode: 1380/5000, Steps: 275997, Avg. Reward (100): -178.50, Epsilon: 0.05, Avg. Loss: 170.7447
# Episode: 1390/5000, Steps: 277997, Avg. Reward (100): -193.90, Epsilon: 0.05, Avg. Loss: 115.7181
# Episode: 1400/5000, Steps: 279997, Avg. Reward (100): -195.70, Epsilon: 0.05, Avg. Loss: 96.4633
# Episode: 1410/5000, Steps: 281997, Avg. Reward (100): -215.80, Epsilon: 0.05, Avg. Loss: 89.5199
# Episode: 1420/5000, Steps: 283997, Avg. Reward (100): -194.30, Epsilon: 0.05, Avg. Loss: 87.9855
# Episode: 1430/5000, Steps: 285997, Avg. Reward (100): -200.40, Epsilon: 0.05, Avg. Loss: 51.9482
# Episode: 1440/5000, Steps: 287997, Avg. Reward (100): -194.30, Epsilon: 0.05, Avg. Loss: 73.2987
# Episode: 1450/5000, Steps: 289997, Avg. Reward (100): -174.30, Epsilon: 0.05, Avg. Loss: 77.4790
# Episode: 1460/5000, Steps: 291997, Avg. Reward (100): -184.60, Epsilon: 0.05, Avg. Loss: 102.2614
# Episode: 1470/5000, Steps: 293997, Avg. Reward (100): -218.50, Epsilon: 0.05, Avg. Loss: 131.3185
# Episode: 1480/5000, Steps: 295997, Avg. Reward (100): -240.40, Epsilon: 0.05, Avg. Loss: 128.9556
# Episode: 1490/5000, Steps: 297997, Avg. Reward (100): -233.30, Epsilon: 0.05, Avg. Loss: 168.8792
# Episode: 1500/5000, Steps: 299997, Avg. Reward (100): -238.60, Epsilon: 0.05, Avg. Loss: 111.9765
# Episode: 1510/5000, Steps: 301997, Avg. Reward (100): -222.10, Epsilon: 0.05, Avg. Loss: 169.8803
# Episode: 1520/5000, Steps: 303997, Avg. Reward (100): -232.60, Epsilon: 0.05, Avg. Loss: 146.0732
# Episode: 1530/5000, Steps: 305997, Avg. Reward (100): -241.40, Epsilon: 0.05, Avg. Loss: 211.9745
# Episode: 1540/5000, Steps: 307997, Avg. Reward (100): -240.60, Epsilon: 0.05, Avg. Loss: 221.8198
# Episode: 1550/5000, Steps: 309997, Avg. Reward (100): -244.40, Epsilon: 0.05, Avg. Loss: 243.4227
# Episode: 1560/5000, Steps: 311997, Avg. Reward (100): -238.40, Epsilon: 0.05, Avg. Loss: 110.6582
# Episode: 1570/5000, Steps: 313997, Avg. Reward (100): -205.20, Epsilon: 0.05, Avg. Loss: 329.6733
# Episode: 1580/5000, Steps: 315997, Avg. Reward (100): -188.20, Epsilon: 0.05, Avg. Loss: 451.8839
# Episode: 1590/5000, Steps: 317997, Avg. Reward (100): -211.80, Epsilon: 0.05, Avg. Loss: 544.3073
# Episode: 1600/5000, Steps: 319997, Avg. Reward (100): -203.50, Epsilon: 0.05, Avg. Loss: 604.5557
# Episode: 1610/5000, Steps: 321997, Avg. Reward (100): -204.80, Epsilon: 0.05, Avg. Loss: 895.1148
# Episode: 1620/5000, Steps: 323997, Avg. Reward (100): -185.60, Epsilon: 0.05, Avg. Loss: 745.2552
# Episode: 1630/5000, Steps: 325997, Avg. Reward (100): -164.80, Epsilon: 0.05, Avg. Loss: 963.7408
# Episode: 1640/5000, Steps: 327997, Avg. Reward (100): -173.70, Epsilon: 0.05, Avg. Loss: 1041.8414
# Episode: 1650/5000, Steps: 329997, Avg. Reward (100): -179.50, Epsilon: 0.05, Avg. Loss: 805.0262
# Episode: 1660/5000, Steps: 331997, Avg. Reward (100): -177.40, Epsilon: 0.05, Avg. Loss: 1046.7048
# Episode: 1670/5000, Steps: 333997, Avg. Reward (100): -172.10, Epsilon: 0.05, Avg. Loss: 778.1869
# Episode: 1680/5000, Steps: 335997, Avg. Reward (100): -159.10, Epsilon: 0.05, Avg. Loss: 784.7077
# Episode: 1690/5000, Steps: 337997, Avg. Reward (100): -122.40, Epsilon: 0.05, Avg. Loss: 658.8311
# Episode: 1700/5000, Steps: 339997, Avg. Reward (100): -119.10, Epsilon: 0.05, Avg. Loss: 497.6887
# Episode: 1710/5000, Steps: 341997, Avg. Reward (100): -125.70, Epsilon: 0.05, Avg. Loss: 467.6314
# Episode: 1720/5000, Steps: 343997, Avg. Reward (100): -126.50, Epsilon: 0.05, Avg. Loss: 421.0643
# Episode: 1730/5000, Steps: 345997, Avg. Reward (100): -127.40, Epsilon: 0.05, Avg. Loss: 488.2817
# Episode: 1740/5000, Steps: 347997, Avg. Reward (100): -124.70, Epsilon: 0.05, Avg. Loss: 345.6783
# Episode: 1750/5000, Steps: 349997, Avg. Reward (100): -119.40, Epsilon: 0.05, Avg. Loss: 564.3385
# Episode: 1760/5000, Steps: 351997, Avg. Reward (100): -127.10, Epsilon: 0.05, Avg. Loss: 365.1580
# Episode: 1770/5000, Steps: 353997, Avg. Reward (100): -126.40, Epsilon: 0.05, Avg. Loss: 914.0243
# Episode: 1780/5000, Steps: 355997, Avg. Reward (100): -123.00, Epsilon: 0.05, Avg. Loss: 1024.5322
# Episode: 1790/5000, Steps: 357997, Avg. Reward (100): -126.20, Epsilon: 0.05, Avg. Loss: 1514.2282
# Episode: 1800/5000, Steps: 359997, Avg. Reward (100): -153.60, Epsilon: 0.05, Avg. Loss: 2284.8304
# Episode: 1810/5000, Steps: 361997, Avg. Reward (100): -157.30, Epsilon: 0.05, Avg. Loss: 3312.3500
# Episode: 1820/5000, Steps: 363997, Avg. Reward (100): -175.90, Epsilon: 0.05, Avg. Loss: 2800.9357
# Episode: 1830/5000, Steps: 365997, Avg. Reward (100): -175.00, Epsilon: 0.05, Avg. Loss: 2780.5933
# Episode: 1840/5000, Steps: 367997, Avg. Reward (100): -167.30, Epsilon: 0.05, Avg. Loss: 1891.9310
# Episode: 1850/5000, Steps: 369997, Avg. Reward (100): -164.60, Epsilon: 0.05, Avg. Loss: 5139.0812
# Episode: 1860/5000, Steps: 371997, Avg. Reward (100): -153.90, Epsilon: 0.05, Avg. Loss: 3072.3084
# Episode: 1870/5000, Steps: 373997, Avg. Reward (100): -163.70, Epsilon: 0.05, Avg. Loss: 4278.4667
# Episode: 1880/5000, Steps: 375997, Avg. Reward (100): -164.10, Epsilon: 0.05, Avg. Loss: 6315.3067
# Episode: 1890/5000, Steps: 377997, Avg. Reward (100): -165.00, Epsilon: 0.05, Avg. Loss: 5777.8815
# Episode: 1900/5000, Steps: 379997, Avg. Reward (100): -164.40, Epsilon: 0.05, Avg. Loss: 11574.7833
# Episode: 1910/5000, Steps: 381997, Avg. Reward (100): -148.80, Epsilon: 0.05, Avg. Loss: 17531.5406
# Episode: 1920/5000, Steps: 383997, Avg. Reward (100): -130.80, Epsilon: 0.05, Avg. Loss: 13804.4098
# Episode: 1930/5000, Steps: 385997, Avg. Reward (100): -130.00, Epsilon: 0.05, Avg. Loss: 11943.9709
# Episode: 1940/5000, Steps: 387997, Avg. Reward (100): -132.70, Epsilon: 0.05, Avg. Loss: 8459.5663
# Episode: 1950/5000, Steps: 389997, Avg. Reward (100): -125.50, Epsilon: 0.05, Avg. Loss: 11113.6741
# Episode: 1960/5000, Steps: 391997, Avg. Reward (100): -153.00, Epsilon: 0.05, Avg. Loss: 12495.1313
# Episode: 1970/5000, Steps: 393997, Avg. Reward (100): -183.90, Epsilon: 0.05, Avg. Loss: 11192.8557
# Episode: 1980/5000, Steps: 395997, Avg. Reward (100): -188.20, Epsilon: 0.05, Avg. Loss: 12217.1541
# Episode: 1990/5000, Steps: 397997, Avg. Reward (100): -200.50, Epsilon: 0.05, Avg. Loss: 9837.6516
# Episode: 2000/5000, Steps: 399997, Avg. Reward (100): -179.70, Epsilon: 0.05, Avg. Loss: 8620.4954
# Episode: 2010/5000, Steps: 401997, Avg. Reward (100): -196.00, Epsilon: 0.05, Avg. Loss: 10980.7699
# Episode: 2020/5000, Steps: 403997, Avg. Reward (100): -190.10, Epsilon: 0.05, Avg. Loss: 10192.9138
# Episode: 2030/5000, Steps: 405997, Avg. Reward (100): -211.70, Epsilon: 0.05, Avg. Loss: 8485.2645
# Episode: 2040/5000, Steps: 407997, Avg. Reward (100): -237.60, Epsilon: 0.05, Avg. Loss: 8909.9430
# Episode: 2050/5000, Steps: 409997, Avg. Reward (100): -240.10, Epsilon: 0.05, Avg. Loss: 6599.3762
# Episode: 2060/5000, Steps: 411997, Avg. Reward (100): -217.00, Epsilon: 0.05, Avg. Loss: 7978.0587
# Episode: 2070/5000, Steps: 413997, Avg. Reward (100): -169.00, Epsilon: 0.05, Avg. Loss: 7313.9339
# Episode: 2080/5000, Steps: 415997, Avg. Reward (100): -166.50, Epsilon: 0.05, Avg. Loss: 6573.7192
# Episode: 2090/5000, Steps: 417997, Avg. Reward (100): -148.20, Epsilon: 0.05, Avg. Loss: 11301.9593
# Episode: 2100/5000, Steps: 419997, Avg. Reward (100): -160.90, Epsilon: 0.05, Avg. Loss: 10596.0939
# Episode: 2110/5000, Steps: 421997, Avg. Reward (100): -144.90, Epsilon: 0.05, Avg. Loss: 12716.7162
# Episode: 2120/5000, Steps: 423997, Avg. Reward (100): -163.90, Epsilon: 0.05, Avg. Loss: 11570.4132
# Episode: 2130/5000, Steps: 425997, Avg. Reward (100): -141.30, Epsilon: 0.05, Avg. Loss: 8408.7600
# Episode: 2140/5000, Steps: 427997, Avg. Reward (100): -122.60, Epsilon: 0.05, Avg. Loss: 11589.8559
# Episode: 2150/5000, Steps: 429997, Avg. Reward (100): -115.80, Epsilon: 0.05, Avg. Loss: 10458.3545
# Episode: 2160/5000, Steps: 431997, Avg. Reward (100): -113.80, Epsilon: 0.05, Avg. Loss: 8951.4506
# Episode: 2170/5000, Steps: 433997, Avg. Reward (100): -131.80, Epsilon: 0.05, Avg. Loss: 6532.3017
# Episode: 2180/5000, Steps: 435997, Avg. Reward (100): -142.30, Epsilon: 0.05, Avg. Loss: 5278.2127
# Episode: 2190/5000, Steps: 437997, Avg. Reward (100): -137.60, Epsilon: 0.05, Avg. Loss: 7147.6313
# Episode: 2200/5000, Steps: 439997, Avg. Reward (100): -136.70, Epsilon: 0.05, Avg. Loss: 8756.9451
# Episode: 2210/5000, Steps: 441997, Avg. Reward (100): -138.30, Epsilon: 0.05, Avg. Loss: 9683.4785
# Episode: 2220/5000, Steps: 443997, Avg. Reward (100): -125.20, Epsilon: 0.05, Avg. Loss: 10149.1620
# Episode: 2230/5000, Steps: 445997, Avg. Reward (100): -139.00, Epsilon: 0.05, Avg. Loss: 16157.4928
# Episode: 2240/5000, Steps: 447997, Avg. Reward (100): -131.40, Epsilon: 0.05, Avg. Loss: 10375.3980
# Episode: 2250/5000, Steps: 449997, Avg. Reward (100): -140.90, Epsilon: 0.05, Avg. Loss: 12611.1886
# Episode: 2260/5000, Steps: 451997, Avg. Reward (100): -134.90, Epsilon: 0.05, Avg. Loss: 13885.6918
# Episode: 2270/5000, Steps: 453997, Avg. Reward (100): -120.00, Epsilon: 0.05, Avg. Loss: 15609.6400
# Episode: 2280/5000, Steps: 455997, Avg. Reward (100): -99.60, Epsilon: 0.05, Avg. Loss: 15389.3800
# Episode: 2290/5000, Steps: 457997, Avg. Reward (100): -108.70, Epsilon: 0.05, Avg. Loss: 14408.1215
# Episode: 2300/5000, Steps: 459997, Avg. Reward (100): -110.20, Epsilon: 0.05, Avg. Loss: 19740.6183
# Episode: 2310/5000, Steps: 461997, Avg. Reward (100): -123.90, Epsilon: 0.05, Avg. Loss: 24678.1996
# Episode: 2320/5000, Steps: 463997, Avg. Reward (100): -123.70, Epsilon: 0.05, Avg. Loss: 17188.0117
# Episode: 2330/5000, Steps: 465997, Avg. Reward (100): -128.60, Epsilon: 0.05, Avg. Loss: 15350.9861
# Episode: 2340/5000, Steps: 467997, Avg. Reward (100): -145.50, Epsilon: 0.05, Avg. Loss: 31731.5681
# Episode: 2350/5000, Steps: 469997, Avg. Reward (100): -137.50, Epsilon: 0.05, Avg. Loss: 20643.5581
# Episode: 2360/5000, Steps: 471997, Avg. Reward (100): -137.80, Epsilon: 0.05, Avg. Loss: 31381.4856
# Episode: 2370/5000, Steps: 473997, Avg. Reward (100): -139.70, Epsilon: 0.05, Avg. Loss: 23672.2157
# Episode: 2380/5000, Steps: 475997, Avg. Reward (100): -139.40, Epsilon: 0.05, Avg. Loss: 28782.6117
# Episode: 2390/5000, Steps: 477997, Avg. Reward (100): -134.10, Epsilon: 0.05, Avg. Loss: 41804.2380
# Episode: 2400/5000, Steps: 479997, Avg. Reward (100): -130.80, Epsilon: 0.05, Avg. Loss: 47673.4044
# Episode: 2410/5000, Steps: 481997, Avg. Reward (100): -134.70, Epsilon: 0.05, Avg. Loss: 73657.2335
# Episode: 2420/5000, Steps: 483997, Avg. Reward (100): -153.10, Epsilon: 0.05, Avg. Loss: 51502.9410
# Episode: 2430/5000, Steps: 485997, Avg. Reward (100): -158.00, Epsilon: 0.05, Avg. Loss: 41121.0750
# Episode: 2440/5000, Steps: 487997, Avg. Reward (100): -150.70, Epsilon: 0.05, Avg. Loss: 42097.5752
# Episode: 2450/5000, Steps: 489997, Avg. Reward (100): -156.00, Epsilon: 0.05, Avg. Loss: 72835.4622
# Episode: 2460/5000, Steps: 491997, Avg. Reward (100): -229.50, Epsilon: 0.05, Avg. Loss: 84707.6978
# Episode: 2470/5000, Steps: 493997, Avg. Reward (100): -249.80, Epsilon: 0.05, Avg. Loss: 88200.0892
# Episode: 2480/5000, Steps: 495997, Avg. Reward (100): -271.00, Epsilon: 0.05, Avg. Loss: 129991.4438
# Episode: 2490/5000, Steps: 497997, Avg. Reward (100): -268.20, Epsilon: 0.05, Avg. Loss: 134184.8238
# Episode: 2500/5000, Steps: 499997, Avg. Reward (100): -278.30, Epsilon: 0.05, Avg. Loss: 272780.4564
# Episode: 2510/5000, Steps: 501997, Avg. Reward (100): -319.10, Epsilon: 0.05, Avg. Loss: 345055.9262
# Episode: 2520/5000, Steps: 503997, Avg. Reward (100): -295.00, Epsilon: 0.05, Avg. Loss: 262797.9880
# Episode: 2530/5000, Steps: 505997, Avg. Reward (100): -290.80, Epsilon: 0.05, Avg. Loss: 1051082.9821
# Episode: 2540/5000, Steps: 507997, Avg. Reward (100): -294.30, Epsilon: 0.05, Avg. Loss: 769479.4423
# Episode: 2550/5000, Steps: 509997, Avg. Reward (100): -294.40, Epsilon: 0.05, Avg. Loss: 1003013.5441
# Episode: 2560/5000, Steps: 511997, Avg. Reward (100): -249.30, Epsilon: 0.05, Avg. Loss: 1329400.9605
# Episode: 2570/5000, Steps: 513997, Avg. Reward (100): -232.60, Epsilon: 0.05, Avg. Loss: 1994501.2775
# Episode: 2580/5000, Steps: 515997, Avg. Reward (100): -225.40, Epsilon: 0.05, Avg. Loss: 1572207.3678
# Episode: 2590/5000, Steps: 517997, Avg. Reward (100): -233.30, Epsilon: 0.05, Avg. Loss: 2339448.5792
# Episode: 2600/5000, Steps: 519997, Avg. Reward (100): -207.30, Epsilon: 0.05, Avg. Loss: 2390346.0111
# Episode: 2610/5000, Steps: 521997, Avg. Reward (100): -163.20, Epsilon: 0.05, Avg. Loss: 1879465.2664
# Episode: 2620/5000, Steps: 523997, Avg. Reward (100): -180.30, Epsilon: 0.05, Avg. Loss: 1664763.2944
# Episode: 2630/5000, Steps: 525997, Avg. Reward (100): -175.10, Epsilon: 0.05, Avg. Loss: 2838020.1706
# Episode: 2640/5000, Steps: 527997, Avg. Reward (100): -161.50, Epsilon: 0.05, Avg. Loss: 3461363.4348
# Episode: 2650/5000, Steps: 529997, Avg. Reward (100): -157.90, Epsilon: 0.05, Avg. Loss: 1660374.5923
# Episode: 2660/5000, Steps: 531997, Avg. Reward (100): -147.10, Epsilon: 0.05, Avg. Loss: 2696145.8694
# Episode: 2670/5000, Steps: 533997, Avg. Reward (100): -141.30, Epsilon: 0.05, Avg. Loss: 2904719.1150
# Episode: 2680/5000, Steps: 535997, Avg. Reward (100): -156.80, Epsilon: 0.05, Avg. Loss: 2871501.6525
# Episode: 2690/5000, Steps: 537997, Avg. Reward (100): -153.40, Epsilon: 0.05, Avg. Loss: 2374712.4225
# Episode: 2700/5000, Steps: 539997, Avg. Reward (100): -159.40, Epsilon: 0.05, Avg. Loss: 3102274.7941
# Episode: 2710/5000, Steps: 541997, Avg. Reward (100): -142.90, Epsilon: 0.05, Avg. Loss: 2349881.3802
# Episode: 2720/5000, Steps: 543997, Avg. Reward (100): -126.10, Epsilon: 0.05, Avg. Loss: 2163215.0256
# Episode: 2730/5000, Steps: 545997, Avg. Reward (100): -112.10, Epsilon: 0.05, Avg. Loss: 2395032.1938
# Episode: 2740/5000, Steps: 547997, Avg. Reward (100): -122.70, Epsilon: 0.05, Avg. Loss: 3085174.3244
# Episode: 2750/5000, Steps: 549997, Avg. Reward (100): -122.00, Epsilon: 0.05, Avg. Loss: 3692218.4638
# Episode: 2760/5000, Steps: 551997, Avg. Reward (100): -112.60, Epsilon: 0.05, Avg. Loss: 2907537.7154
# Episode: 2770/5000, Steps: 553997, Avg. Reward (100): -118.00, Epsilon: 0.05, Avg. Loss: 6389883.7014
# Episode: 2780/5000, Steps: 555997, Avg. Reward (100): -109.00, Epsilon: 0.05, Avg. Loss: 4257047.3681
# Episode: 2790/5000, Steps: 557997, Avg. Reward (100): -98.10, Epsilon: 0.05, Avg. Loss: 5107255.3600
# Episode: 2800/5000, Steps: 559997, Avg. Reward (100): -109.70, Epsilon: 0.05, Avg. Loss: 7311760.8344
# Episode: 2810/5000, Steps: 561997, Avg. Reward (100): -120.60, Epsilon: 0.05, Avg. Loss: 7669885.2956
# Episode: 2820/5000, Steps: 563997, Avg. Reward (100): -140.30, Epsilon: 0.05, Avg. Loss: 7422242.7344
# Episode: 2830/5000, Steps: 565997, Avg. Reward (100): -148.80, Epsilon: 0.05, Avg. Loss: 12937340.2566
# Episode: 2840/5000, Steps: 567997, Avg. Reward (100): -147.20, Epsilon: 0.05, Avg. Loss: 7394610.9044
# Episode: 2850/5000, Steps: 569997, Avg. Reward (100): -147.70, Epsilon: 0.05, Avg. Loss: 8815053.9422
# Episode: 2860/5000, Steps: 571997, Avg. Reward (100): -143.40, Epsilon: 0.05, Avg. Loss: 11143237.0344
# Episode: 2870/5000, Steps: 573997, Avg. Reward (100): -150.60, Epsilon: 0.05, Avg. Loss: 12307524.4544
# Episode: 2880/5000, Steps: 575997, Avg. Reward (100): -131.60, Epsilon: 0.05, Avg. Loss: 13018570.9094
# Episode: 2890/5000, Steps: 577997, Avg. Reward (100): -152.30, Epsilon: 0.05, Avg. Loss: 13368946.4600
# Episode: 2900/5000, Steps: 579997, Avg. Reward (100): -136.90, Epsilon: 0.05, Avg. Loss: 12695685.4356
# Episode: 2910/5000, Steps: 581997, Avg. Reward (100): -136.20, Epsilon: 0.05, Avg. Loss: 11670892.4669
# Episode: 2920/5000, Steps: 583997, Avg. Reward (100): -136.90, Epsilon: 0.05, Avg. Loss: 14152395.8138
# Episode: 2930/5000, Steps: 585997, Avg. Reward (100): -136.40, Epsilon: 0.05, Avg. Loss: 11392926.5687
# Episode: 2940/5000, Steps: 587997, Avg. Reward (100): -137.30, Epsilon: 0.05, Avg. Loss: 9942020.6919
# Episode: 2950/5000, Steps: 589997, Avg. Reward (100): -137.00, Epsilon: 0.05, Avg. Loss: 15679818.5234
# Episode: 2960/5000, Steps: 591997, Avg. Reward (100): -135.10, Epsilon: 0.05, Avg. Loss: 7986774.2387
# Episode: 2970/5000, Steps: 593997, Avg. Reward (100): -125.00, Epsilon: 0.05, Avg. Loss: 11441254.0269
# Episode: 2980/5000, Steps: 595997, Avg. Reward (100): -126.10, Epsilon: 0.05, Avg. Loss: 7998444.8150
# Episode: 2990/5000, Steps: 597997, Avg. Reward (100): -122.50, Epsilon: 0.05, Avg. Loss: 13660023.3869
# Episode: 3000/5000, Steps: 599997, Avg. Reward (100): -122.80, Epsilon: 0.05, Avg. Loss: 9614535.5503
# Episode: 3010/5000, Steps: 601997, Avg. Reward (100): -120.80, Epsilon: 0.05, Avg. Loss: 14028316.6250
# Episode: 3020/5000, Steps: 603997, Avg. Reward (100): -117.00, Epsilon: 0.05, Avg. Loss: 19128489.2494
# Episode: 3030/5000, Steps: 605997, Avg. Reward (100): -117.50, Epsilon: 0.05, Avg. Loss: 25696542.7600
# Episode: 3040/5000, Steps: 607997, Avg. Reward (100): -112.30, Epsilon: 0.05, Avg. Loss: 30583110.3950
# Episode: 3050/5000, Steps: 609997, Avg. Reward (100): -111.60, Epsilon: 0.05, Avg. Loss: 52462919.2175
# Episode: 3060/5000, Steps: 611997, Avg. Reward (100): -124.70, Epsilon: 0.05, Avg. Loss: 95842807.7150
# Episode: 3070/5000, Steps: 613997, Avg. Reward (100): -130.30, Epsilon: 0.05, Avg. Loss: 108370519.0450
# Episode: 3080/5000, Steps: 615997, Avg. Reward (100): -152.00, Epsilon: 0.05, Avg. Loss: 103235435.8900
# Episode: 3090/5000, Steps: 617997, Avg. Reward (100): -146.20, Epsilon: 0.05, Avg. Loss: 267542412.7200
# Episode: 3100/5000, Steps: 619997, Avg. Reward (100): -146.00, Epsilon: 0.05, Avg. Loss: 234677139.3900
# Episode: 3110/5000, Steps: 621997, Avg. Reward (100): -147.30, Epsilon: 0.05, Avg. Loss: 212669495.2000
# Episode: 3120/5000, Steps: 623997, Avg. Reward (100): -135.30, Epsilon: 0.05, Avg. Loss: 487532616.9200
# Episode: 3130/5000, Steps: 625997, Avg. Reward (100): -146.10, Epsilon: 0.05, Avg. Loss: 302767024.4600
# Episode: 3140/5000, Steps: 627997, Avg. Reward (100): -142.90, Epsilon: 0.05, Avg. Loss: 336481217.4600
# Episode: 3150/5000, Steps: 629997, Avg. Reward (100): -148.10, Epsilon: 0.05, Avg. Loss: 256441041.9400
# Episode: 3160/5000, Steps: 631997, Avg. Reward (100): -135.40, Epsilon: 0.05, Avg. Loss: 347832942.7400
# Episode: 3170/5000, Steps: 633997, Avg. Reward (100): -125.90, Epsilon: 0.05, Avg. Loss: 471574948.5600
# Episode: 3180/5000, Steps: 635997, Avg. Reward (100): -131.10, Epsilon: 0.05, Avg. Loss: 428887495.5600
# Episode: 3190/5000, Steps: 637997, Avg. Reward (100): -119.20, Epsilon: 0.05, Avg. Loss: 565120403.8800
# Episode: 3200/5000, Steps: 639997, Avg. Reward (100): -129.20, Epsilon: 0.05, Avg. Loss: 552442502.3000
# Episode: 3210/5000, Steps: 641997, Avg. Reward (100): -124.40, Epsilon: 0.05, Avg. Loss: 706585443.0200
# Episode: 3220/5000, Steps: 643997, Avg. Reward (100): -131.40, Epsilon: 0.05, Avg. Loss: 577528718.1200
# Episode: 3230/5000, Steps: 645997, Avg. Reward (100): -115.10, Epsilon: 0.05, Avg. Loss: 903659524.6400
# Episode: 3240/5000, Steps: 647997, Avg. Reward (100): -120.10, Epsilon: 0.05, Avg. Loss: 516198228.2400
# Episode: 3250/5000, Steps: 649997, Avg. Reward (100): -121.10, Epsilon: 0.05, Avg. Loss: 561053898.3200
# Episode: 3260/5000, Steps: 651997, Avg. Reward (100): -118.90, Epsilon: 0.05, Avg. Loss: 547708691.4400
# Episode: 3270/5000, Steps: 653997, Avg. Reward (100): -130.70, Epsilon: 0.05, Avg. Loss: 670463928.8000
# Episode: 3280/5000, Steps: 655997, Avg. Reward (100): -110.30, Epsilon: 0.05, Avg. Loss: 898825390.6400
# Episode: 3290/5000, Steps: 657997, Avg. Reward (100): -116.30, Epsilon: 0.05, Avg. Loss: 650562271.3200
# Episode: 3300/5000, Steps: 659997, Avg. Reward (100): -111.90, Epsilon: 0.05, Avg. Loss: 618078127.8400
# Episode: 3310/5000, Steps: 661997, Avg. Reward (100): -111.50, Epsilon: 0.05, Avg. Loss: 707312994.1600
# Episode: 3320/5000, Steps: 663997, Avg. Reward (100): -112.40, Epsilon: 0.05, Avg. Loss: 708486220.2800
# Episode: 3330/5000, Steps: 665997, Avg. Reward (100): -136.10, Epsilon: 0.05, Avg. Loss: 748477838.8000
# Episode: 3340/5000, Steps: 667997, Avg. Reward (100): -165.90, Epsilon: 0.05, Avg. Loss: 564123040.2000
# Episode: 3350/5000, Steps: 669997, Avg. Reward (100): -173.30, Epsilon: 0.05, Avg. Loss: 803923315.9200
# Episode: 3360/5000, Steps: 671997, Avg. Reward (100): -189.30, Epsilon: 0.05, Avg. Loss: 656639011.1600
# Episode: 3370/5000, Steps: 673997, Avg. Reward (100): -181.30, Epsilon: 0.05, Avg. Loss: 902503555.9200
# Episode: 3380/5000, Steps: 675997, Avg. Reward (100): -189.90, Epsilon: 0.05, Avg. Loss: 808446557.6800
# Episode: 3390/5000, Steps: 677997, Avg. Reward (100): -197.70, Epsilon: 0.05, Avg. Loss: 576393000.8000
# Episode: 3400/5000, Steps: 679997, Avg. Reward (100): -202.70, Epsilon: 0.05, Avg. Loss: 559666272.8200
# Episode: 3410/5000, Steps: 681997, Avg. Reward (100): -217.20, Epsilon: 0.05, Avg. Loss: 888752851.5200
# Episode: 3420/5000, Steps: 683997, Avg. Reward (100): -209.60, Epsilon: 0.05, Avg. Loss: 759019193.0800
# Episode: 3430/5000, Steps: 685997, Avg. Reward (100): -183.40, Epsilon: 0.05, Avg. Loss: 677289253.8400
# Episode: 3440/5000, Steps: 687997, Avg. Reward (100): -153.10, Epsilon: 0.05, Avg. Loss: 1134691530.8600
# Episode: 3450/5000, Steps: 689997, Avg. Reward (100): -139.70, Epsilon: 0.05, Avg. Loss: 583792745.0400
# Episode: 3460/5000, Steps: 691997, Avg. Reward (100): -134.80, Epsilon: 0.05, Avg. Loss: 607453208.1800
# Episode: 3470/5000, Steps: 693997, Avg. Reward (100): -138.80, Epsilon: 0.05, Avg. Loss: 550766206.7200
# Episode: 3480/5000, Steps: 695997, Avg. Reward (100): -146.10, Epsilon: 0.05, Avg. Loss: 554592552.1200
# Episode: 3490/5000, Steps: 697997, Avg. Reward (100): -145.20, Epsilon: 0.05, Avg. Loss: 371279760.1800
# Episode: 3500/5000, Steps: 699997, Avg. Reward (100): -143.10, Epsilon: 0.05, Avg. Loss: 433418906.1200
# Episode: 3510/5000, Steps: 701997, Avg. Reward (100): -127.10, Epsilon: 0.05, Avg. Loss: 331666331.2800
# Episode: 3520/5000, Steps: 703997, Avg. Reward (100): -123.60, Epsilon: 0.05, Avg. Loss: 393353297.3600
# Episode: 3530/5000, Steps: 705997, Avg. Reward (100): -124.10, Epsilon: 0.05, Avg. Loss: 337491862.8600
# Episode: 3540/5000, Steps: 707997, Avg. Reward (100): -125.10, Epsilon: 0.05, Avg. Loss: 338195082.7800
# Episode: 3550/5000, Steps: 709997, Avg. Reward (100): -136.50, Epsilon: 0.05, Avg. Loss: 295877962.6200
# Episode: 3560/5000, Steps: 711997, Avg. Reward (100): -137.90, Epsilon: 0.05, Avg. Loss: 326694773.5000
# Episode: 3570/5000, Steps: 713997, Avg. Reward (100): -142.20, Epsilon: 0.05, Avg. Loss: 375749635.8000
# Episode: 3580/5000, Steps: 715997, Avg. Reward (100): -127.50, Epsilon: 0.05, Avg. Loss: 215806965.4400
# Episode: 3590/5000, Steps: 717997, Avg. Reward (100): -121.60, Epsilon: 0.05, Avg. Loss: 208353664.3300
# Episode: 3600/5000, Steps: 719997, Avg. Reward (100): -111.40, Epsilon: 0.05, Avg. Loss: 178129672.3300
# Episode: 3610/5000, Steps: 721997, Avg. Reward (100): -107.80, Epsilon: 0.05, Avg. Loss: 143927903.2900
# Episode: 3620/5000, Steps: 723997, Avg. Reward (100): -112.10, Epsilon: 0.05, Avg. Loss: 211339557.5600
# Episode: 3630/5000, Steps: 725997, Avg. Reward (100): -113.70, Epsilon: 0.05, Avg. Loss: 185389489.9700
# Episode: 3640/5000, Steps: 727997, Avg. Reward (100): -105.00, Epsilon: 0.05, Avg. Loss: 132921544.5700
# Episode: 3650/5000, Steps: 729997, Avg. Reward (100): -102.60, Epsilon: 0.05, Avg. Loss: 114585063.7400
# Episode: 3660/5000, Steps: 731997, Avg. Reward (100): -93.90, Epsilon: 0.05, Avg. Loss: 93597707.0800
# Episode: 3670/5000, Steps: 733997, Avg. Reward (100): -91.30, Epsilon: 0.05, Avg. Loss: 78817215.7000
# Episode: 3680/5000, Steps: 735997, Avg. Reward (100): -81.50, Epsilon: 0.05, Avg. Loss: 113378142.1100
# Episode: 3690/5000, Steps: 737997, Avg. Reward (100): -87.80, Epsilon: 0.05, Avg. Loss: 83686928.7000
# Episode: 3700/5000, Steps: 739997, Avg. Reward (100): -129.00, Epsilon: 0.05, Avg. Loss: 72118570.9750
# Episode: 3710/5000, Steps: 741997, Avg. Reward (100): -140.60, Epsilon: 0.05, Avg. Loss: 79002548.0250
# Episode: 3720/5000, Steps: 743997, Avg. Reward (100): -176.00, Epsilon: 0.05, Avg. Loss: 59516355.0000
# Episode: 3730/5000, Steps: 745997, Avg. Reward (100): -219.90, Epsilon: 0.05, Avg. Loss: 67707189.0500
# Episode: 3740/5000, Steps: 747997, Avg. Reward (100): -272.60, Epsilon: 0.05, Avg. Loss: 91248902.2600
# Episode: 3750/5000, Steps: 749997, Avg. Reward (100): -305.40, Epsilon: 0.05, Avg. Loss: 54425641.9850
# Episode: 3760/5000, Steps: 751997, Avg. Reward (100): -337.00, Epsilon: 0.05, Avg. Loss: 65370717.8700
# Episode: 3770/5000, Steps: 753997, Avg. Reward (100): -362.10, Epsilon: 0.05, Avg. Loss: 63977330.2200
# Episode: 3780/5000, Steps: 755997, Avg. Reward (100): -422.70, Epsilon: 0.05, Avg. Loss: 55782484.8900
# Episode: 3790/5000, Steps: 757997, Avg. Reward (100): -455.40, Epsilon: 0.05, Avg. Loss: 49248961.8350
# Episode: 3800/5000, Steps: 759997, Avg. Reward (100): -442.70, Epsilon: 0.05, Avg. Loss: 63728741.8500
# Episode: 3810/5000, Steps: 761997, Avg. Reward (100): -472.90, Epsilon: 0.05, Avg. Loss: 54741207.7650
# Episode: 3820/5000, Steps: 763997, Avg. Reward (100): -432.00, Epsilon: 0.05, Avg. Loss: 85904446.7600
# Episode: 3830/5000, Steps: 765997, Avg. Reward (100): -424.60, Epsilon: 0.05, Avg. Loss: 84094191.7250
# Episode: 3840/5000, Steps: 767997, Avg. Reward (100): -418.70, Epsilon: 0.05, Avg. Loss: 55424778.9900
# Episode: 3850/5000, Steps: 769997, Avg. Reward (100): -391.60, Epsilon: 0.05, Avg. Loss: 58854297.2675
# Episode: 3860/5000, Steps: 771997, Avg. Reward (100): -363.80, Epsilon: 0.05, Avg. Loss: 34544218.3325
# Episode: 3870/5000, Steps: 773997, Avg. Reward (100): -341.10, Epsilon: 0.05, Avg. Loss: 38292144.5900
# Episode: 3880/5000, Steps: 775997, Avg. Reward (100): -296.20, Epsilon: 0.05, Avg. Loss: 37990083.8675
# Episode: 3890/5000, Steps: 777997, Avg. Reward (100): -268.70, Epsilon: 0.05, Avg. Loss: 25850473.0212
# Episode: 3900/5000, Steps: 779997, Avg. Reward (100): -240.80, Epsilon: 0.05, Avg. Loss: 40797143.4338
# Episode: 3910/5000, Steps: 781997, Avg. Reward (100): -199.90, Epsilon: 0.05, Avg. Loss: 19803369.5963
# Episode: 3920/5000, Steps: 783997, Avg. Reward (100): -213.30, Epsilon: 0.05, Avg. Loss: 32471736.0800
# Episode: 3930/5000, Steps: 785997, Avg. Reward (100): -188.60, Epsilon: 0.05, Avg. Loss: 16748303.7912
# Episode: 3940/5000, Steps: 787997, Avg. Reward (100): -152.30, Epsilon: 0.05, Avg. Loss: 16990204.5338
# Episode: 3950/5000, Steps: 789997, Avg. Reward (100): -181.50, Epsilon: 0.05, Avg. Loss: 11507780.6738
# Episode: 3960/5000, Steps: 791997, Avg. Reward (100): -208.30, Epsilon: 0.05, Avg. Loss: 14067287.5687
# Episode: 3970/5000, Steps: 793997, Avg. Reward (100): -211.40, Epsilon: 0.05, Avg. Loss: 12415668.3069
# Episode: 3980/5000, Steps: 795997, Avg. Reward (100): -222.00, Epsilon: 0.05, Avg. Loss: 9596524.1269
# Episode: 3990/5000, Steps: 797997, Avg. Reward (100): -246.10, Epsilon: 0.05, Avg. Loss: 13121110.8928
# Episode: 4000/5000, Steps: 799997, Avg. Reward (100): -276.20, Epsilon: 0.05, Avg. Loss: 17778620.7969
# Episode: 4010/5000, Steps: 801997, Avg. Reward (100): -282.40, Epsilon: 0.05, Avg. Loss: 9926859.8041
# Episode: 4020/5000, Steps: 803997, Avg. Reward (100): -298.70, Epsilon: 0.05, Avg. Loss: 9022802.5744
# Episode: 4030/5000, Steps: 805997, Avg. Reward (100): -284.60, Epsilon: 0.05, Avg. Loss: 9161575.8112
# Episode: 4040/5000, Steps: 807997, Avg. Reward (100): -282.40, Epsilon: 0.05, Avg. Loss: 6790639.6203
# Episode: 4050/5000, Steps: 809997, Avg. Reward (100): -243.10, Epsilon: 0.05, Avg. Loss: 8809844.5675
# Episode: 4060/5000, Steps: 811997, Avg. Reward (100): -213.20, Epsilon: 0.05, Avg. Loss: 6762480.7613
# Episode: 4070/5000, Steps: 813997, Avg. Reward (100): -206.80, Epsilon: 0.05, Avg. Loss: 6775283.9197
# Episode: 4080/5000, Steps: 815997, Avg. Reward (100): -182.10, Epsilon: 0.05, Avg. Loss: 5761560.8384
# Episode: 4090/5000, Steps: 817997, Avg. Reward (100): -140.80, Epsilon: 0.05, Avg. Loss: 5682955.0306
# Episode: 4100/5000, Steps: 819997, Avg. Reward (100): -114.20, Epsilon: 0.05, Avg. Loss: 5796606.4581
# Episode: 4110/5000, Steps: 821997, Avg. Reward (100): -137.90, Epsilon: 0.05, Avg. Loss: 6580444.2659
# Episode: 4120/5000, Steps: 823997, Avg. Reward (100): -109.80, Epsilon: 0.05, Avg. Loss: 6394943.8800
# Episode: 4130/5000, Steps: 825997, Avg. Reward (100): -123.80, Epsilon: 0.05, Avg. Loss: 5807682.1875
# Episode: 4140/5000, Steps: 827997, Avg. Reward (100): -127.40, Epsilon: 0.05, Avg. Loss: 10861508.6713
# Episode: 4150/5000, Steps: 829997, Avg. Reward (100): -128.60, Epsilon: 0.05, Avg. Loss: 11595337.7637
# Episode: 4160/5000, Steps: 831997, Avg. Reward (100): -138.50, Epsilon: 0.05, Avg. Loss: 14029207.4075
# Episode: 4170/5000, Steps: 833997, Avg. Reward (100): -135.50, Epsilon: 0.05, Avg. Loss: 8292912.7381
# Episode: 4180/5000, Steps: 835997, Avg. Reward (100): -141.50, Epsilon: 0.05, Avg. Loss: 6005048.1087
# Episode: 4190/5000, Steps: 837997, Avg. Reward (100): -145.90, Epsilon: 0.05, Avg. Loss: 9199722.5900
# Episode: 4200/5000, Steps: 839997, Avg. Reward (100): -167.00, Epsilon: 0.05, Avg. Loss: 4329988.4406
# Episode: 4210/5000, Steps: 841997, Avg. Reward (100): -158.50, Epsilon: 0.05, Avg. Loss: 4761275.3900
# Episode: 4220/5000, Steps: 843997, Avg. Reward (100): -160.30, Epsilon: 0.05, Avg. Loss: 7225717.2469
# Episode: 4230/5000, Steps: 845997, Avg. Reward (100): -157.90, Epsilon: 0.05, Avg. Loss: 3959659.0784
# Episode: 4240/5000, Steps: 847997, Avg. Reward (100): -174.20, Epsilon: 0.05, Avg. Loss: 4249242.4586
# Episode: 4250/5000, Steps: 849997, Avg. Reward (100): -177.10, Epsilon: 0.05, Avg. Loss: 4460606.7663
# Episode: 4260/5000, Steps: 851997, Avg. Reward (100): -174.80, Epsilon: 0.05, Avg. Loss: 6171355.6425
# Episode: 4270/5000, Steps: 853997, Avg. Reward (100): -183.60, Epsilon: 0.05, Avg. Loss: 7634080.5888
# Episode: 4280/5000, Steps: 855997, Avg. Reward (100): -184.10, Epsilon: 0.05, Avg. Loss: 9660473.0050
# Episode: 4290/5000, Steps: 857997, Avg. Reward (100): -219.10, Epsilon: 0.05, Avg. Loss: 8424893.2519
# Episode: 4300/5000, Steps: 859997, Avg. Reward (100): -211.30, Epsilon: 0.05, Avg. Loss: 7533775.3950
# Episode: 4310/5000, Steps: 861997, Avg. Reward (100): -205.10, Epsilon: 0.05, Avg. Loss: 9478491.1531
# Episode: 4320/5000, Steps: 863997, Avg. Reward (100): -231.60, Epsilon: 0.05, Avg. Loss: 13882435.9150
# Episode: 4330/5000, Steps: 865997, Avg. Reward (100): -237.40, Epsilon: 0.05, Avg. Loss: 9591088.7531
# Episode: 4340/5000, Steps: 867997, Avg. Reward (100): -243.70, Epsilon: 0.05, Avg. Loss: 9498638.7044
# Episode: 4350/5000, Steps: 869997, Avg. Reward (100): -259.00, Epsilon: 0.05, Avg. Loss: 9078406.9056
# Episode: 4360/5000, Steps: 871997, Avg. Reward (100): -270.70, Epsilon: 0.05, Avg. Loss: 7642341.2616
# Episode: 4370/5000, Steps: 873997, Avg. Reward (100): -282.60, Epsilon: 0.05, Avg. Loss: 4499617.1837
# Episode: 4380/5000, Steps: 875997, Avg. Reward (100): -290.30, Epsilon: 0.05, Avg. Loss: 4902684.6953
# Episode: 4390/5000, Steps: 877997, Avg. Reward (100): -263.60, Epsilon: 0.05, Avg. Loss: 7838417.3291
# Episode: 4400/5000, Steps: 879997, Avg. Reward (100): -257.40, Epsilon: 0.05, Avg. Loss: 5205476.3177
# Episode: 4410/5000, Steps: 881997, Avg. Reward (100): -247.30, Epsilon: 0.05, Avg. Loss: 2569130.8134
# Episode: 4420/5000, Steps: 883997, Avg. Reward (100): -225.80, Epsilon: 0.05, Avg. Loss: 3120245.8703
# Episode: 4430/5000, Steps: 885997, Avg. Reward (100): -219.10, Epsilon: 0.05, Avg. Loss: 2123370.6136
# Episode: 4440/5000, Steps: 887997, Avg. Reward (100): -190.20, Epsilon: 0.05, Avg. Loss: 5834703.7047
# Episode: 4450/5000, Steps: 889997, Avg. Reward (100): -174.40, Epsilon: 0.05, Avg. Loss: 2451741.3406
# Episode: 4460/5000, Steps: 891997, Avg. Reward (100): -158.30, Epsilon: 0.05, Avg. Loss: 1723266.0810
# Episode: 4470/5000, Steps: 893997, Avg. Reward (100): -145.90, Epsilon: 0.05, Avg. Loss: 4522665.8813
# Episode: 4480/5000, Steps: 895997, Avg. Reward (100): -155.60, Epsilon: 0.05, Avg. Loss: 3353270.6203
# Episode: 4490/5000, Steps: 897997, Avg. Reward (100): -148.90, Epsilon: 0.05, Avg. Loss: 7567372.7616
# Episode: 4500/5000, Steps: 899997, Avg. Reward (100): -144.50, Epsilon: 0.05, Avg. Loss: 7719865.6331
# Episode: 4510/5000, Steps: 901997, Avg. Reward (100): -160.20, Epsilon: 0.05, Avg. Loss: 12833700.7781
# Episode: 4520/5000, Steps: 903997, Avg. Reward (100): -179.70, Epsilon: 0.05, Avg. Loss: 11078945.6363
# Episode: 4530/5000, Steps: 905997, Avg. Reward (100): -191.10, Epsilon: 0.05, Avg. Loss: 9041822.7700
# Episode: 4540/5000, Steps: 907997, Avg. Reward (100): -200.50, Epsilon: 0.05, Avg. Loss: 7072057.1550
# Episode: 4550/5000, Steps: 909997, Avg. Reward (100): -194.60, Epsilon: 0.05, Avg. Loss: 9736942.7819
# Episode: 4560/5000, Steps: 911997, Avg. Reward (100): -186.80, Epsilon: 0.05, Avg. Loss: 10527190.4162
# Episode: 4570/5000, Steps: 913997, Avg. Reward (100): -180.30, Epsilon: 0.05, Avg. Loss: 5099960.3600
# Episode: 4580/5000, Steps: 915997, Avg. Reward (100): -155.70, Epsilon: 0.05, Avg. Loss: 6508307.1869
# Episode: 4590/5000, Steps: 917997, Avg. Reward (100): -161.50, Epsilon: 0.05, Avg. Loss: 5665022.8887
# Episode: 4600/5000, Steps: 919997, Avg. Reward (100): -156.10, Epsilon: 0.05, Avg. Loss: 20810023.8300
# Episode: 4610/5000, Steps: 921997, Avg. Reward (100): -147.20, Epsilon: 0.05, Avg. Loss: 19012541.0150
# Episode: 4620/5000, Steps: 923997, Avg. Reward (100): -119.70, Epsilon: 0.05, Avg. Loss: 11625690.4325
# Episode: 4630/5000, Steps: 925997, Avg. Reward (100): -131.60, Epsilon: 0.05, Avg. Loss: 17124980.5375
# Episode: 4640/5000, Steps: 927997, Avg. Reward (100): -148.00, Epsilon: 0.05, Avg. Loss: 20576893.4187
# Episode: 4650/5000, Steps: 929997, Avg. Reward (100): -157.70, Epsilon: 0.05, Avg. Loss: 10461897.4413
# Episode: 4660/5000, Steps: 931997, Avg. Reward (100): -166.00, Epsilon: 0.05, Avg. Loss: 16044213.3400
# Episode: 4670/5000, Steps: 933997, Avg. Reward (100): -157.10, Epsilon: 0.05, Avg. Loss: 8847702.4675
# Episode: 4680/5000, Steps: 935997, Avg. Reward (100): -166.00, Epsilon: 0.05, Avg. Loss: 9928346.0900
# Episode: 4690/5000, Steps: 937997, Avg. Reward (100): -164.10, Epsilon: 0.05, Avg. Loss: 8513765.9250
# Episode: 4700/5000, Steps: 939997, Avg. Reward (100): -163.70, Epsilon: 0.05, Avg. Loss: 13371353.8675
# Episode: 4710/5000, Steps: 941997, Avg. Reward (100): -158.20, Epsilon: 0.05, Avg. Loss: 11230236.5062
# Episode: 4720/5000, Steps: 943997, Avg. Reward (100): -192.80, Epsilon: 0.05, Avg. Loss: 15058399.5075
# Episode: 4730/5000, Steps: 945997, Avg. Reward (100): -200.70, Epsilon: 0.05, Avg. Loss: 13172678.1450
# Episode: 4740/5000, Steps: 947997, Avg. Reward (100): -198.40, Epsilon: 0.05, Avg. Loss: 7324152.2387
# Episode: 4750/5000, Steps: 949997, Avg. Reward (100): -198.40, Epsilon: 0.05, Avg. Loss: 13823418.8313
# Episode: 4760/5000, Steps: 951997, Avg. Reward (100): -204.60, Epsilon: 0.05, Avg. Loss: 9412791.1662
# Episode: 4770/5000, Steps: 953997, Avg. Reward (100): -225.10, Epsilon: 0.05, Avg. Loss: 8825040.3475
# Episode: 4780/5000, Steps: 955997, Avg. Reward (100): -237.80, Epsilon: 0.05, Avg. Loss: 12080028.9038
# Episode: 4790/5000, Steps: 957997, Avg. Reward (100): -246.90, Epsilon: 0.05, Avg. Loss: 12669870.0475
# Episode: 4800/5000, Steps: 959997, Avg. Reward (100): -255.50, Epsilon: 0.05, Avg. Loss: 21814533.1725
# Episode: 4810/5000, Steps: 961997, Avg. Reward (100): -260.20, Epsilon: 0.05, Avg. Loss: 19141220.7613
# Episode: 4820/5000, Steps: 963997, Avg. Reward (100): -231.80, Epsilon: 0.05, Avg. Loss: 6565890.5631
# Episode: 4830/5000, Steps: 965997, Avg. Reward (100): -203.30, Epsilon: 0.05, Avg. Loss: 11993460.1650
# Episode: 4840/5000, Steps: 967997, Avg. Reward (100): -184.20, Epsilon: 0.05, Avg. Loss: 11384219.2228
# Episode: 4850/5000, Steps: 969997, Avg. Reward (100): -183.70, Epsilon: 0.05, Avg. Loss: 14281671.2037
# Episode: 4860/5000, Steps: 971997, Avg. Reward (100): -212.20, Epsilon: 0.05, Avg. Loss: 6784199.2519
# Episode: 4870/5000, Steps: 973997, Avg. Reward (100): -254.00, Epsilon: 0.05, Avg. Loss: 6801365.8706
# Episode: 4880/5000, Steps: 975997, Avg. Reward (100): -249.00, Epsilon: 0.05, Avg. Loss: 7241024.9500
# Episode: 4890/5000, Steps: 977997, Avg. Reward (100): -279.60, Epsilon: 0.05, Avg. Loss: 9701042.1844
# Episode: 4900/5000, Steps: 979997, Avg. Reward (100): -293.80, Epsilon: 0.05, Avg. Loss: 8881698.5819
# Episode: 4910/5000, Steps: 981997, Avg. Reward (100): -290.00, Epsilon: 0.05, Avg. Loss: 5453045.6431
# Episode: 4920/5000, Steps: 983997, Avg. Reward (100): -294.80, Epsilon: 0.05, Avg. Loss: 8638460.8087
# Episode: 4930/5000, Steps: 985997, Avg. Reward (100): -317.80, Epsilon: 0.05, Avg. Loss: 9704909.1387
# Episode: 4940/5000, Steps: 987997, Avg. Reward (100): -325.10, Epsilon: 0.05, Avg. Loss: 13397695.8156
# Episode: 4950/5000, Steps: 989997, Avg. Reward (100): -338.10, Epsilon: 0.05, Avg. Loss: 9636187.7930
# Episode: 4960/5000, Steps: 991997, Avg. Reward (100): -308.90, Epsilon: 0.05, Avg. Loss: 5693295.5444
# Episode: 4970/5000, Steps: 993997, Avg. Reward (100): -307.30, Epsilon: 0.05, Avg. Loss: 20057586.4081
# Episode: 4980/5000, Steps: 995997, Avg. Reward (100): -338.80, Epsilon: 0.05, Avg. Loss: 8198796.7819
# Episode: 4990/5000, Steps: 997997, Avg. Reward (100): -308.00, Epsilon: 0.05, Avg. Loss: 11269214.7525
# --- QMIX Learning Finished ---

# %%
from IPython import display # Jupyter環境用（オプション）

def run_learned_agent(agent: IntegratedQMixAgent, env: WarehouseEnv, max_steps: int = 100, render_mode: str = 'graphic', sleep_time: float = 0.5):
    """
    学習済みエージェントを環境内で実行し、その動作を可視化する。

    Args:
        agent (IntegratedQMixAgent): 学習済みのQMIXエージェントインスタンス。
        env (WarehouseEnv): 倉庫環境インスタンス。
        max_steps (int): エピソードの最大ステップ数。
        render_mode (str): 'graphic' または 'text'。
        sleep_time (float): 各ステップ間の待機時間（グラフィックモード時）。
    """

    print("\n--- Running Learned Agent (Greedy Policy) ---")

    # 1. 環境の初期化
    obs = env.reset()
    agent.init_hidden() # エピソード開始時に隠れ状態をリセット
    current_state_obs = obs

    episode_reward = 0
    done = {i: False for i in range(env.num_agents)}

    # 2. ネットワークを評価モードに設定 (ドロップアウトなどを無効化)
    agent.agent_net.eval()

    for step in range(max_steps):
        # 3. 行動の選択 (epsilon=0、貪欲法)
        # 実行時はHidden Stateの更新も必要
        actions = agent.get_actions(current_state_obs, epsilon=0.0) # 探索なし

        # 4. 環境との相互作用
        next_obs, rewards, done, info = env.step(actions)

        # 5. 可視化
        if render_mode == 'graphic':
            env.render(mode='graphic', sleep_time=sleep_time)
        else:
            env.render(mode='text', sleep_time=0.0)

        # 6. 報酬の集計と状態の更新
        episode_reward += sum(rewards.values())
        current_state_obs = next_obs

        print(f"Step {step+1}: Actions={actions}, Total Reward={sum(rewards.values()):.1f}, Cum. Reward={episode_reward:.1f}")

        if all(done.values()):
            print(f"--- Episode Finished at Step {step+1} (Total Reward: {episode_reward:.1f}) ---")
            break

    if not all(done.values()):
        print(f"--- Episode Finished by Timeout (Max Steps: {max_steps}) (Total Reward: {episode_reward:.1f}) ---")


# 実行部分の開始...
run_learned_agent(
    agent=agent,
    env=env,
    max_steps=200,
    render_mode='graphic',
    sleep_time=0.3
)
# Out:
# --- Running Learned Agent (Greedy Policy) ---
# Step 1: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-0.2
# Step 2: Actions={0: 1, 1: 4}, Total Reward=-0.2, Cum. Reward=-0.4
# Step 3: Actions={0: 1, 1: 4}, Total Reward=-0.2, Cum. Reward=-0.6
# Step 4: Actions={0: 1, 1: 4}, Total Reward=-0.2, Cum. Reward=-0.8
# Step 5: Actions={0: 1, 1: 0}, Total Reward=-0.2, Cum. Reward=-1.0
# Step 6: Actions={0: 1, 1: 4}, Total Reward=-0.2, Cum. Reward=-1.2
# Step 7: Actions={0: 1, 1: 0}, Total Reward=-0.2, Cum. Reward=-1.4
# Step 8: Actions={0: 1, 1: 0}, Total Reward=-0.2, Cum. Reward=-1.6
# Step 9: Actions={0: 1, 1: 4}, Total Reward=-0.2, Cum. Reward=-1.8
# Step 10: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-2.0
# Step 11: Actions={0: 1, 1: 4}, Total Reward=-0.2, Cum. Reward=-2.2
# Step 12: Actions={0: 1, 1: 4}, Total Reward=-0.2, Cum. Reward=-2.4
# Step 13: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-2.6
# Step 14: Actions={0: 1, 1: 4}, Total Reward=-0.2, Cum. Reward=-2.8
# Step 15: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-3.0
# Step 16: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-3.2
# Step 17: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-3.4
# Step 18: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-3.6
# Step 19: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-3.8
# Step 20: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-4.0
# Step 21: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-4.2
# Step 22: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-4.4
# Step 23: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-4.6
# Step 24: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-4.8
# Step 25: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-5.0
# Step 26: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-5.2
# Step 27: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-5.4
# Step 28: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-5.6
# Step 29: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-5.8
# Step 30: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-6.0
# Step 31: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-6.2
# Step 32: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-6.4
# Step 33: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-6.6
# Step 34: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-6.8
# Step 35: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-7.0
# Step 36: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-7.2
# Step 37: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-7.4
# Step 38: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-7.6
# Step 39: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-7.8
# Step 40: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-8.0
# Step 41: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-8.2
# Step 42: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-8.4
# Step 43: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-8.6
# Step 44: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-8.8
# Step 45: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-9.0
# Step 46: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-9.2
# Step 47: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-9.4
# Step 48: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-9.6
# Step 49: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-9.8
# Step 50: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-10.0
# Step 51: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-10.2
# Step 52: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-10.4
# Step 53: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-10.6
# Step 54: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-10.8
# Step 55: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-11.0
# Step 56: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-11.2
# Step 57: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-11.4
# Step 58: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-11.6
# Step 59: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-11.8
# Step 60: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-12.0
# Step 61: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-12.2
# Step 62: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-12.4
# Step 63: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-12.6
# Step 64: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-12.8
# Step 65: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-13.0
# Step 66: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-13.2
# Step 67: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-13.4
# Step 68: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-13.6
# Step 69: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-13.8
# Step 70: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-14.0
# Step 71: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-14.2
# Step 72: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-14.4
# Step 73: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-14.6
# Step 74: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-14.8
# Step 75: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-15.0
# Step 76: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-15.2
# Step 77: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-15.4
# Step 78: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-15.6
# Step 79: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-15.8
# Step 80: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-16.0
# Step 81: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-16.2
# Step 82: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-16.4
# Step 83: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-16.6
# Step 84: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-16.8
# Step 85: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-17.0
# Step 86: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-17.2
# Step 87: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-17.4
# Step 88: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-17.6
# Step 89: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-17.8
# Step 90: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-18.0
# Step 91: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-18.2
# Step 92: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-18.4
# Step 93: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-18.6
# Step 94: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-18.8
# Step 95: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-19.0
# Step 96: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-19.2
# Step 97: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-19.4
# Step 98: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-19.6
# Step 99: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-19.8
# Step 100: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-20.0
# Step 101: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-20.2
# Step 102: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-20.4
# Step 103: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-20.6
# Step 104: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-20.8
# Step 105: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-21.0
# Step 106: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-21.2
# Step 107: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-21.4
# Step 108: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-21.6
# Step 109: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-21.8
# Step 110: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-22.0
# Step 111: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-22.2
# Step 112: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-22.4
# Step 113: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-22.6
# Step 114: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-22.8
# Step 115: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-23.0
# Step 116: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-23.2
# Step 117: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-23.4
# Step 118: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-23.6
# Step 119: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-23.8
# Step 120: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-24.0
# Step 121: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-24.2
# Step 122: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-24.4
# Step 123: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-24.6
# Step 124: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-24.8
# Step 125: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-25.0
# Step 126: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-25.2
# Step 127: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-25.4
# Step 128: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-25.6
# Step 129: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-25.8
# Step 130: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-26.0
# Step 131: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-26.2
# Step 132: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-26.4
# Step 133: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-26.6
# Step 134: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-26.8
# Step 135: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-27.0
# Step 136: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-27.2
# Step 137: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-27.4
# Step 138: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-27.6
# Step 139: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-27.8
# Step 140: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-28.0
# Step 141: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-28.2
# Step 142: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-28.4
# Step 143: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-28.6
# Step 144: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-28.8
# Step 145: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-29.0
# Step 146: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-29.2
# Step 147: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-29.4
# Step 148: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-29.6
# Step 149: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-29.8
# Step 150: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-30.0
# Step 151: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-30.2
# Step 152: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-30.4
# Step 153: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-30.6
# Step 154: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-30.8
# Step 155: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-31.0
# Step 156: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-31.2
# Step 157: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-31.4
# Step 158: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-31.6
# Step 159: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-31.8
# Step 160: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-32.0
# Step 161: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-32.2
# Step 162: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-32.4
# Step 163: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-32.6
# Step 164: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-32.8
# Step 165: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-33.0
# Step 166: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-33.2
# Step 167: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-33.4
# Step 168: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-33.6
# Step 169: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-33.8
# Step 170: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-34.0
# Step 171: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-34.2
# Step 172: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-34.4
# Step 173: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-34.6
# Step 174: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-34.8
# Step 175: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-35.0
# Step 176: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-35.2
# Step 177: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-35.4
# Step 178: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-35.6
# Step 179: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-35.8
# Step 180: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-36.0
# Step 181: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-36.2
# Step 182: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-36.4
# Step 183: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-36.6
# Step 184: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-36.8
# Step 185: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-37.0
# Step 186: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-37.2
# Step 187: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-37.4
# Step 188: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-37.6
# Step 189: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-37.8
# Step 190: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-38.0
# Step 191: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-38.2
# Step 192: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-38.4
# Step 193: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-38.6
# Step 194: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-38.8
# Step 195: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-39.0
# Step 196: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-39.2
# Step 197: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-39.4
# Step 198: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-39.6
# Step 199: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-39.8
# Step 200: Actions={0: 2, 1: 4}, Total Reward=-0.2, Cum. Reward=-40.0
# --- Episode Finished by Timeout (Max Steps: 200) (Total Reward: -40.0) ---

# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt

def run_and_save_gif(agent, env, filename: str, max_steps: int = 1, fps: int = 10):
    """
    学習済みエージェントを環境内で実行し、その動作をGIFファイルとして保存する。

    Args:
        agent (IntegratedQMixAgent): 学習済みのQMIXエージェントインスタンス。
        env (WarehouseEnv): 倉庫環境インスタンス。
        filename (str): 保存するGIFファイルの名前 (例: "warehouse_run.gif")。
        max_steps (int): エピソードの最大ステップ数。
        fps (int): GIFのフレームレート（1秒あたりのコマ数）。
    """

    # 描画の初期設定 (環境のfig, axを再利用または新規作成)
    if env.fig is None:
        plt.ioff() # アニメーション中はインタラクティブモードをオフにする
        env.fig, env.ax = plt.subplots(figsize=(6, 6))
    else:
        # 既存の図をクリアして再利用
        env.fig.clf()
        env.ax = env.fig.add_subplot(111)
        plt.ioff()

    # 1. 環境の初期化
    obs = env.reset()
    agent.init_hidden() # エピソード開始時に隠れ状態をリセット
    current_state_obs = obs

    episode_reward = 0
    done = {i: False for i in range(env.num_agents)}
    frames = []

    # 2. ネットワークを評価モードに設定 (ドロップアウトなどを無効化)
    agent.agent_net.eval()
    print(f"\n--- Running and Saving GIF: {filename} (Max Steps: {max_steps}, FPS: {fps}) ---")

    for step in range(max_steps):
        print(f"Processing Step {step+1}/{max_steps}...") # 進行状況の確認

        # 3, 4. 行動選択と環境ステップ
        actions = agent.get_actions(current_state_obs, epsilon=0.0)
        next_obs, rewards, done, info = env.step(actions)

        # 5. フレームのキャプチャ

        # (a) 環境の描画データを Figure に書き込む (Step 1の修正後、描画設定のみ実行)
        env._render_graphic(sleep_time=0.0)
        print("hi")
        # (b) Figure を強制的にレンダリングし、キャプチャを可能にする
        env.fig.canvas.draw()

        # (c) レンダリングされた結果をバイトデータとして取得
        # 'tostring_argb' は処理が重いことが知られています。
        # 処理が進まない場合は、以下の行で停止している可能性が高いです。

        # 描画された図をRGBA画像としてキャプチャ
        image = np.frombuffer(env.fig.canvas.tostring_argb(), dtype='uint8')
        image = image.reshape(env.fig.canvas.get_width_height()[::-1] + (4,))

        # RGBA -> RGBに変換し、リストに追加
        frames.append(image[:, :, 1:]) # [:, :, 1:] で ARGB から RGB に変換

        # 6. 報酬の集計と状態の更新
        episode_reward += sum(rewards.values())
        current_state_obs = next_obs

        if all(done.values()):
            print(f"--- Episode Finished at Step {step+1} (Total Reward: {episode_reward:.1f}) ---")
            # 終了後、最後のフレームを数枚追加して停止を強調 (任意)
            for _ in range(fps * 2): # 2秒間停止
                frames.append(image[:, :, 1:])
            break


    # 7. GIFファイルの作成と保存
    print("🎨 GIFファイルを生成中...")

    # GIF作成のためのFuncAnimation用のヘルパー関数
    def animate(i):
        env.ax.clear()
        env.ax.set_title(f"Step {i+1} / Reward: {episode_reward:.1f}")
        # フレームリストから画像を読み込み、描画する (ここではFuncAnimationは使わず、直接保存ロジックを記述します)
        # FuncAnimationはインタラクティブ描画用なので、ここではPIL/ImageIOなどを使うのが一般的ですが、
        # Matplotlibの推奨する方法で保存します。

    # Imageioなどの外部ライブラリを使わず、Matplotlibのアニメーションモジュールで直接保存する

    # 描画関数を定義 (フレームの内容を更新する)
    def update_frame(i):
        env.ax.clear()
        # ここで直接 env._render_graphic のロジックを再実行する必要がある
        # しかし、framesリストに画像データが格納されているので、それを表示するシンプルな関数が必要です。

        # MatplotlibのAnimationは、通常、描画オブジェクトを返す必要があります。
        # シンプルな手順として、ImageioまたはPillow (PIL) を使用してフレームリストを直接GIFに変換します。

    # --- 代替案: ImageIO/Pillowによる直接保存 ---
    try:
        from PIL import Image
    except ImportError:
        print("PIL (Pillow) がインストールされていません。`!pip install Pillow` を実行してください。")
        return

    images = [Image.fromarray(frame).convert('RGB') for frame in frames]

    # GIFの保存
    if not images:
        print("フレームがありません。GIF保存をスキップします。")
        return

    save_path = os.path.join(os.getcwd(), filename)
    images[0].save(
        save_path,
        save_all=True,
        append_images=images[1:],
        duration=int(1000 / fps), # durationはミリ秒単位
        # loop=0 # 0は無限ループ
    )
    plt.close(env.fig) # 図を閉じる
    env.fig = None
    print(f"✅ GIFを '{save_path}' に保存しました。")


### 3. 実行例
# --- 実行に必要なライブラリのインストール ---
# !pip install Pillow

# --- 実行 ---
# GIFファイル名、最大ステップ数、フレームレートを設定
GIF_FILENAME = "qmix_warehouse_run.gif"
FPS = 15 # 1秒間に15コマ

# 実行
run_and_save_gif(
    agent=agent,
    env=env,
    filename=GIF_FILENAME,
    max_steps=80,
    fps=FPS
)
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
#
# --- Running and Saving GIF: qmix_warehouse_run.gif (Max Steps: 80, FPS: 15) ---
# Processing Step 1/80...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-366090013.py in <cell line: 0>()
#      70
#      71 # 実行
# ---> 72 run_and_save_gif(
#      73     agent=agent,
#      74     env=env,
#
# /tmp/ipython-input-3882974817.py in run_and_save_gif(agent, env, filename, max_steps, fps)
#      49
#      50         # (a) 環境の描画データを Figure に書き込む (Step 1の修正後、描画設定のみ実行)
# ---> 51         env._render_graphic(sleep_time=0.0)
#      52         print("hi")
#      53         # (b) Figure を強制的にレンダリングし、キャプチャを可能にする
#
# /tmp/ipython-input-3937570555.py in _render_graphic(self, sleep_time)
#     184
#     185         plt.draw()
# --> 186         plt.pause(sleep_time)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in pause(interval)
#     756             canvas.draw_idle()
#     757         show(block=False)
# --> 758         canvas.start_event_loop(interval)
#     759     else:
#     760         time.sleep(interval)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in start_event_loop(self, timeout)
#    2363         while self._looping and counter * timestep < timeout:
#    2364             self.flush_events()
# -> 2365             time.sleep(timestep)
#    2366             counter += 1
#    2367
#
# KeyboardInterrupt:

# %%
from google.colab import drive
import os

# Google Driveをマウント
drive.mount('/content/drive')

# モデルを保存するディレクトリ
MODEL_SAVE_PATH = '/content/drive/MyDrive/QMIX_Warehouse_Models/'
os.makedirs(MODEL_SAVE_PATH, exist_ok=True)

import torch

def save_qmix_model(agent: IntegratedQMixAgent, filename: str):
    """
    QMIXモデルの重み（state_dict）をファイルに保存します。
    """

    # ターゲットネットワークは保存せず、学習用ネットワークのみ保存します。
    model_data = {
        'agent_net_state_dict': agent.agent_net.state_dict(),
        'mixer_net_state_dict': agent.mixer_net.state_dict(),
        'optimizer_state_dict': agent.optimizer.state_dict(), # オプティマイザの状態も保存することで、学習を再開できます
        # その他、学習に必要なメタデータ（ハイパーパラメータなど）も保存できます
    }

    save_path = os.path.join(MODEL_SAVE_PATH, filename)
    torch.save(model_data, save_path)
    print(f"✅ モデルの重みを '{save_path}' に保存しました。")

# --- 実行 ---
# 例: 最終学習ステップのモデルを保存
save_qmix_model(agent, "qmix_warehouse_final.pth")
# Out:
# Mounted at /content/drive
# ✅ モデルの重みを '/content/drive/MyDrive/QMIX_Warehouse_Models/qmix_warehouse_final.pth' に保存しました。

# %%
from google.colab import drive
import os
import torch

# Google Driveをマウント（まだマウントされていない場合）
try:
    drive.mount('/content/drive')
except:
    # 既にマウント済みの場合やエラー処理
    pass

# モデルを保存/ロードするディレクトリ (保存時と同じパスを使用)
MODEL_SAVE_PATH = '/content/drive/MyDrive/QMIX_Warehouse_Models/'

def load_qmix_model(agent: IntegratedQMixAgent, filename: str, optimizer_load: bool = False):
    """
    指定されたファイルからQMIXモデルの重み（state_dict）をロードし、エージェントに適用します。

    Args:
        agent (IntegratedQMixAgent): 重みをロードする対象のエージェントインスタンス。
        filename (str): ロードするモデルファイル名 (例: "qmix_warehouse_final.pth")。
        optimizer_load (bool): オプティマイザの状態もロードするかどうか。
                               (学習を再開する場合に True にする)
    """
    load_path = os.path.join(MODEL_SAVE_PATH, filename)

    if not os.path.exists(load_path):
        print(f"❌ エラー: ファイル '{load_path}' が見つかりません。")
        return

    print(f"⏳ モデルの重みを '{load_path}' からロード中...")

    # CPU/GPUの状態に応じてマップしてロード
    if torch.cuda.is_available():
        map_location = 'cuda'
    else:
        map_location = 'cpu'

    try:
        # ファイルからデータをロード
        model_data = torch.load(load_path, map_location=map_location)

        # 1. Agent Network の重みをロード
        agent.agent_net.load_state_dict(model_data['agent_net_state_dict'])

        # 2. Mixer Network の重みをロード
        agent.mixer_net.load_state_dict(model_data['mixer_net_state_dict'])

        # 3. オプティマイザの状態をロード (必要に応じて)
        if optimizer_load and 'optimizer_state_dict' in model_data:
            agent.optimizer.load_state_dict(model_data['optimizer_state_dict'])
            print("   (オプティマイザの状態もロードしました。)")

        # モデルを評価モードに設定 (推論で使う場合)
        agent.agent_net.eval()
        agent.mixer_net.eval()

        print(f"✅ モデルの重み ({filename}) のロードが完了しました。")

    except Exception as e:
        print(f"❌ モデルのロード中にエラーが発生しました: {e}")

# --- 実行例 ---

# ロード対象のエージェントインスタンス（agent）は、事前に初期化されている必要があります。
# 例: agent = IntegratedQMixAgent(...)

# ⚠️ 注意: ロードを実行する前に、`agent` インスタンスが
# 適切なハイパーパラメータで初期化されていることを確認してください。

# 以前に保存したファイルをロード
LOAD_FILENAME = "qmix_warehouse_final.pth"
load_qmix_model(agent, LOAD_FILENAME, optimizer_load=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ⏳ モデルの重みを '/content/drive/MyDrive/QMIX_Warehouse_Models/qmix_warehouse_final.pth' からロード中...
# ✅ モデルの重み (qmix_warehouse_final.pth) のロードが完了しました。
